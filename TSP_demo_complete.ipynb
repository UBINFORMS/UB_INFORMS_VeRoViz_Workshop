# %% [markdown]
# # An Introduction to VeRoViz - TSP Demo

# %% [markdown]
# May 5th 2020
# - This workshop highlights basic functionality provided in version v0.4.0
# - Python version >= 3.7.2

# %% [markdown]
# ---

# %% [markdown]
# - Let's get started!

# %%
import veroviz as vrv
vrv.checkVersion()
# Out:
# 'Your current installed version of veroviz is 0.4.0. You are up-to-date with the latest available version.'

# %% [markdown]
# ## Generate Nodes

# %% [markdown]
# - Create a depot

# %%
nodes = vrv.createNodesFromLocs(
    locs = [[41.5, -77.5]],
    nodeType = 'Depot',
    leafletColor = 'red'
)

# %% [markdown]
# - Create Customers

# %%
boundingRegion = [[42, -78], [41, -78], [41, -77], [42, -77]]
nodes = vrv.generateNodes(
    initNodes = nodes,
    nodeType = 'Customer',
    numNodes = 12,
    nodeName = 'Customer',
    incrementName = True,
    incrementStart = 1,
    nodeDistrib = 'uniformBB',
    nodeDistribArgs = {
        'boundingRegion' : boundingRegion
    },
    leafletColor = 'green',
    snapToRoad=True,
    dataProvider='osrm-online'
)
nodes
# Out:
# Warning: 'id' in `initNodes` is already larger than `startNode`. Overriding `startNode` with maximum `id` + 1.
#     id        lat        lon altMeters    nodeName  nodeType popupText  \
# 0    1  41.500000 -77.500000         0        None     Depot         1
# 1    2  41.974404 -77.530365         0   Customer1  Customer         2
# 2    3  41.213616 -77.824253         0   Customer2  Customer         3
# 3    4  41.230588 -77.431782         0   Customer3  Customer         4
# 4    5  41.958312 -77.881078         0   Customer4  Customer         5
# 5    6  41.784584 -77.548038         0   Customer5  Customer         6
# 6    7  41.713083 -77.866776         0   Customer6  Customer         7
# 7    8  41.209624 -77.566319         0   Customer7  Customer         8
# 8    9  41.457648 -77.018324         0   Customer8  Customer         9
# 9   10  41.540730 -77.359086         0   Customer9  Customer        10
# 10  11  41.667345 -77.676581         0  Customer10  Customer        11
# 11  12  41.953599 -77.066891         0  Customer11  Customer        12
# 12  13  41.638532 -77.340577         0  Customer12  Customer        13
#
#    leafletIconPrefix leafletIconType leafletColor leafletIconText  \
# 0          glyphicon       info-sign          red               1
# 1          glyphicon       info-sign        green               2
# 2          glyphicon       info-sign        green               3
# 3          glyphicon       info-sign        green               4
# 4          glyphicon       info-sign        green               5
# 5          glyphicon       info-sign        green               6
# 6          glyphicon       info-sign        green               7
# 7          glyphicon       info-sign        green               8
# 8          glyphicon       info-sign        green               9
# 9          glyphicon       info-sign        green              10
# 10         glyphicon       info-sign        green              11
# 11         glyphicon       info-sign        green              12
# 12         glyphicon       info-sign        green              13
#
#    cesiumIconType cesiumColor cesiumIconText elevMeters
# 0             pin        blue              1       None
# 1             pin        blue              2       None
# 2             pin        blue              3       None
# 3             pin        blue              4       None
# 4             pin        blue              5       None
# 5             pin        blue              6       None
# 6             pin        blue              7       None
# 7             pin        blue              8       None
# 8             pin        blue              9       None
# 9             pin        blue             10       None
# 10            pin        blue             11       None
# 11            pin        blue             12       None
# 12            pin        blue             13       None

# %% [markdown]
# - Visualize the nodes we've just created

# %%
vrv.createLeaflet(nodes = nodes, boundingRegion = boundingRegion)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Build Travel Matrices

# %% [markdown]
# - Build Travel Matrices

# %%
travelMatrices = vrv.getTimeDist2D(
    nodes = nodes,
    matrixType = 'all2all',
    routeType = 'fastest',
    dataProvider='osrm-online'
)

# %%
tauTime = travelMatrices[0]
tauDist = travelMatrices[1]

# %% [markdown]
# - Time Matrix

# %%
tauTime
# Out:
# {(1, 1): 0.0,
#  (1, 2): 5357.7,
#  (1, 3): 4930.6,
#  (1, 4): 2646.9,
#  (1, 5): 6275.6,
#  (1, 6): 4404.0,
#  (1, 7): 5995.0,
#  (1, 8): 3790.8,
#  (1, 9): 4325.2,
#  (1, 10): 2353.5,
#  (1, 11): 4362.1,
#  (1, 12): 4449.1,
#  (1, 13): 2867.4,
#  (2, 1): 5541.9,
#  (2, 2): 0.0,
#  (2, 3): 8102.0,
#  (2, 4): 7148.9,
#  (2, 5): 3063.1,
#  (2, 6): 3120.1,
#  (2, 7): 4721.1,
#  (2, 8): 7444.1,
#  (2, 9): 6293.0,
#  (2, 10): 5612.2,
#  (2, 11): 3613.3,
#  (2, 12): 3029.3,
#  (2, 13): 4097.5,
#  (3, 1): 4890.4,
#  (3, 2): 8086.5,
#  (3, 3): 0.0,
#  (3, 4): 3878.5,
#  (3, 5): 7170.6,
#  (3, 6): 6187.3,
#  (3, 7): 5861.7,
#  (3, 8): 2728.0,
#  (3, 9): 6621.0,
#  (3, 10): 7188.6,
#  (3, 11): 4735.9,
#  (3, 12): 8042.7,
#  (3, 13): 7513.3,
#  (4, 1): 2626.0,
#  (4, 2): 7193.5,
#  (4, 3): 3904.3,
#  (4, 4): 0.0,
#  (4, 5): 6277.6,
#  (4, 6): 5294.3,
#  (4, 7): 4968.7,
#  (4, 8): 1952.5,
#  (4, 9): 3819.5,
#  (4, 10): 4559.7,
#  (4, 11): 3842.9,
#  (4, 12): 5562.2,
#  (4, 13): 4970.0,
#  (5, 1): 6188.2,
#  (5, 2): 3168.3,
#  (5, 3): 7142.7,
#  (5, 4): 6189.6,
#  (5, 5): 0.0,
#  (5, 6): 3041.8,
#  (5, 7): 2939.2,
#  (5, 8): 6484.8,
#  (5, 9): 7222.6,
#  (5, 10): 6258.5,
#  (5, 11): 2654.0,
#  (5, 12): 4868.1,
#  (5, 13): 4367.8,
#  (6, 1): 4321.1,
#  (6, 2): 3160.7,
#  (6, 3): 6165.0,
#  (6, 4): 5211.9,
#  (6, 5): 3041.0,
#  (6, 6): 0.0,
#  (6, 7): 3032.0,
#  (6, 8): 5507.1,
#  (6, 9): 5355.5,
#  (6, 10): 4391.4,
#  (6, 11): 1676.3,
#  (6, 12): 3030.1,
#  (6, 13): 2500.7,
#  (7, 1): 5934.2,
#  (7, 2): 4316.3,
#  (7, 3): 5845.7,
#  (7, 4): 4892.6,
#  (7, 5): 2700.5,
#  (7, 6): 2787.8,
#  (7, 7): 0.0,
#  (7, 8): 5187.8,
#  (7, 9): 6968.6,
#  (7, 10): 6004.5,
#  (7, 11): 2183.7,
#  (7, 12): 4643.2,
#  (7, 13): 4113.8,
#  (8, 1): 3796.7,
#  (8, 2): 7515.2,
#  (8, 3): 2763.8,
#  (8, 4): 1956.9,
#  (8, 5): 6599.3,
#  (8, 6): 5616.0,
#  (8, 7): 5290.4,
#  (8, 8): 0.0,
#  (8, 9): 4163.6,
#  (8, 10): 4903.8,
#  (8, 11): 4164.6,
#  (8, 12): 5906.3,
#  (8, 13): 5314.1,
#  (9, 1): 4189.3,
#  (9, 2): 6136.2,
#  (9, 3): 6544.2,
#  (9, 4): 3746.9,
#  (9, 5): 7157.6,
#  (9, 6): 5286.0,
#  (9, 7): 7148.6,
#  (9, 8): 4047.3,
#  (9, 9): 0.0,
#  (9, 10): 4032.1,
#  (9, 11): 5792.9,
#  (9, 12): 3690.6,
#  (9, 13): 3749.4,
#  (10, 1): 2370.9,
#  (10, 2): 5289.4,
#  (10, 3): 7083.9,
#  (10, 4): 4444.9,
#  (10, 5): 6207.3,
#  (10, 6): 4335.7,
#  (10, 7): 6198.3,
#  (10, 8): 4745.3,
#  (10, 9): 3931.2,
#  (10, 10): 0.0,
#  (10, 11): 4842.6,
#  (10, 12): 4335.4,
#  (10, 13): 2799.1,
#  (11, 1): 4207.5,
#  (11, 2): 3667.0,
#  (11, 3): 4802.8,
#  (11, 4): 3849.7,
#  (11, 5): 2751.1,
#  (11, 6): 1767.8,
#  (11, 7): 2267.3,
#  (11, 8): 4144.9,
#  (11, 9): 5948.6,
#  (11, 10): 4984.5,
#  (11, 11): 0.0,
#  (11, 12): 3623.2,
#  (11, 13): 3093.8,
#  (12, 1): 4422.0,
#  (12, 2): 3089.6,
#  (12, 3): 8017.6,
#  (12, 4): 5568.2,
#  (12, 5): 4893.6,
#  (12, 6): 3022.0,
#  (12, 7): 4884.6,
#  (12, 8): 5868.6,
#  (12, 9): 3843.8,
#  (12, 10): 4492.3,
#  (12, 11): 3528.9,
#  (12, 12): 0.0,
#  (12, 13): 2962.4,
#  (13, 1): 2809.4,
#  (13, 2): 3793.6,
#  (13, 3): 7580.5,
#  (13, 4): 4941.5,
#  (13, 5): 4349.9,
#  (13, 6): 2478.3,
#  (13, 7): 4340.9,
#  (13, 8): 5241.9,
#  (13, 9): 3843.8,
#  (13, 10): 2879.7,
#  (13, 11): 2985.2,
#  (13, 12): 2934.6,
#  (13, 13): 0.0}

# %%
tauTimeDF = vrv.convertMatricesDictionaryToDataframe(tauTime)
tauTimeDF
# Out:
#         1       2       3       4       5       6       7       8       9   \
# 1      0.0  5357.7  4930.6  2646.9  6275.6  4404.0  5995.0  3790.8  4325.2
# 2   5541.9     0.0  8102.0  7148.9  3063.1  3120.1  4721.1  7444.1  6293.0
# 3   4890.4  8086.5     0.0  3878.5  7170.6  6187.3  5861.7  2728.0  6621.0
# 4   2626.0  7193.5  3904.3     0.0  6277.6  5294.3  4968.7  1952.5  3819.5
# 5   6188.2  3168.3  7142.7  6189.6     0.0  3041.8  2939.2  6484.8  7222.6
# 6   4321.1  3160.7  6165.0  5211.9  3041.0     0.0  3032.0  5507.1  5355.5
# 7   5934.2  4316.3  5845.7  4892.6  2700.5  2787.8     0.0  5187.8  6968.6
# 8   3796.7  7515.2  2763.8  1956.9  6599.3  5616.0  5290.4     0.0  4163.6
# 9   4189.3  6136.2  6544.2  3746.9  7157.6  5286.0  7148.6  4047.3     0.0
# 10  2370.9  5289.4  7083.9  4444.9  6207.3  4335.7  6198.3  4745.3  3931.2
# 11  4207.5  3667.0  4802.8  3849.7  2751.1  1767.8  2267.3  4144.9  5948.6
# 12  4422.0  3089.6  8017.6  5568.2  4893.6  3022.0  4884.6  5868.6  3843.8
# 13  2809.4  3793.6  7580.5  4941.5  4349.9  2478.3  4340.9  5241.9  3843.8
#
#         10      11      12      13
# 1   2353.5  4362.1  4449.1  2867.4
# 2   5612.2  3613.3  3029.3  4097.5
# 3   7188.6  4735.9  8042.7  7513.3
# 4   4559.7  3842.9  5562.2  4970.0
# 5   6258.5  2654.0  4868.1  4367.8
# 6   4391.4  1676.3  3030.1  2500.7
# 7   6004.5  2183.7  4643.2  4113.8
# 8   4903.8  4164.6  5906.3  5314.1
# 9   4032.1  5792.9  3690.6  3749.4
# 10     0.0  4842.6  4335.4  2799.1
# 11  4984.5     0.0  3623.2  3093.8
# 12  4492.3  3528.9     0.0  2962.4
# 13  2879.7  2985.2  2934.6     0.0

# %% [markdown]
# - Distance Matrix

# %%
tauDist
# Out:
# {(1, 1): 0.0,
#  (1, 2): 87311.2,
#  (1, 3): 84438.6,
#  (1, 4): 47288.3,
#  (1, 5): 114146.5,
#  (1, 6): 73431.9,
#  (1, 7): 106354.8,
#  (1, 8): 71374.4,
#  (1, 9): 75239.6,
#  (1, 10): 27984.0,
#  (1, 11): 40382.8,
#  (1, 12): 93688.7,
#  (1, 13): 39058.5,
#  (2, 1): 90218.4,
#  (2, 2): 0.0,
#  (2, 3): 132001.3,
#  (2, 4): 117734.1,
#  (2, 5): 46215.3,
#  (2, 6): 28344.3,
#  (2, 7): 64490.9,
#  (2, 8): 125125.6,
#  (2, 9): 129457.2,
#  (2, 10): 82226.1,
#  (2, 11): 49963.3,
#  (2, 12): 49618.9,
#  (2, 13): 62375.7,
#  (3, 1): 84438.6,
#  (3, 2): 131789.2,
#  (3, 3): 0.0,
#  (3, 4): 64897.5,
#  (3, 5): 130968.4,
#  (3, 6): 109205.5,
#  (3, 7): 101080.8,
#  (3, 8): 34893.3,
#  (3, 9): 115460.0,
#  (3, 10): 106392.3,
#  (3, 11): 84489.4,
#  (3, 12): 157676.3,
#  (3, 13): 130093.0,
#  (4, 1): 47288.3,
#  (4, 2): 117522.0,
#  (4, 3): 64897.5,
#  (4, 4): 0.0,
#  (4, 5): 116701.2,
#  (4, 6): 94938.3,
#  (4, 7): 86813.6,
#  (4, 8): 31955.8,
#  (4, 9): 74774.5,
#  (4, 10): 72369.3,
#  (4, 11): 70222.2,
#  (4, 12): 141662.3,
#  (4, 13): 87734.4,
#  (5, 1): 114091.8,
#  (5, 2): 46215.3,
#  (5, 3): 130968.4,
#  (5, 4): 116701.2,
#  (5, 5): 0.0,
#  (5, 6): 54238.6,
#  (5, 7): 44057.0,
#  (5, 8): 124092.6,
#  (5, 9): 140374.1,
#  (5, 10): 106099.6,
#  (5, 11): 48930.4,
#  (5, 12): 85137.3,
#  (5, 13): 75126.1,
#  (6, 1): 73377.2,
#  (6, 2): 29748.8,
#  (6, 3): 109205.5,
#  (6, 4): 94938.3,
#  (6, 5): 54238.6,
#  (6, 6): 0.0,
#  (6, 7): 46689.2,
#  (6, 8): 102329.7,
#  (6, 9): 99659.5,
#  (6, 10): 65384.9,
#  (6, 11): 27167.5,
#  (6, 12): 61994.8,
#  (6, 13): 34411.5,
#  (7, 1): 106542.4,
#  (7, 2): 64278.8,
#  (7, 3): 101080.8,
#  (7, 4): 86813.6,
#  (7, 5): 44057.0,
#  (7, 6): 46689.2,
#  (7, 7): 0.0,
#  (7, 8): 94205.1,
#  (7, 9): 132824.7,
#  (7, 10): 98550.2,
#  (7, 11): 33911.2,
#  (7, 12): 95160.0,
#  (7, 13): 67576.7,
#  (8, 1): 71374.4,
#  (8, 2): 124913.5,
#  (8, 3): 34893.3,
#  (8, 4): 31955.8,
#  (8, 5): 124092.6,
#  (8, 6): 102329.7,
#  (8, 7): 94205.1,
#  (8, 8): 0.0,
#  (8, 9): 86469.1,
#  (8, 10): 84064.0,
#  (8, 11): 77613.7,
#  (8, 12): 153357.0,
#  (8, 13): 99429.1,
#  (9, 1): 74049.8,
#  (9, 2): 130231.7,
#  (9, 3): 114357.1,
#  (9, 4): 73650.2,
#  (9, 5): 139198.8,
#  (9, 6): 98484.2,
#  (9, 7): 131649.4,
#  (9, 8): 85366.3,
#  (9, 9): 0.0,
#  (9, 10): 57449.5,
#  (9, 11): 112127.7,
#  (9, 12): 87316.0,
#  (9, 13): 64110.8,
#  (10, 1): 27984.0,
#  (10, 2): 79319.0,
#  (10, 3): 106392.3,
#  (10, 4): 72173.7,
#  (10, 5): 106154.3,
#  (10, 6): 65439.6,
#  (10, 7): 98604.9,
#  (10, 8): 83889.7,
#  (10, 9): 56563.7,
#  (10, 10): 0.0,
#  (10, 11): 79083.1,
#  (10, 12): 80379.2,
#  (10, 13): 31066.2,
#  (11, 1): 40382.8,
#  (11, 2): 49751.2,
#  (11, 3): 84489.4,
#  (11, 4): 70222.2,
#  (11, 5): 48930.4,
#  (11, 6): 27167.5,
#  (11, 7): 33911.2,
#  (11, 8): 77613.7,
#  (11, 9): 113303.0,
#  (11, 10): 79028.4,
#  (11, 11): 0.0,
#  (11, 12): 75638.3,
#  (11, 13): 48055.0,
#  (12, 1): 93639.7,
#  (12, 2): 56942.2,
#  (12, 3): 157656.8,
#  (12, 4): 140720.4,
#  (12, 5): 102689.9,
#  (12, 6): 61975.3,
#  (12, 7): 95140.5,
#  (12, 8): 152436.4,
#  (12, 9): 88765.6,
#  (12, 10): 85647.5,
#  (12, 11): 75618.8,
#  (12, 12): 0.0,
#  (12, 13): 52734.4,
#  (13, 1): 39018.2,
#  (13, 2): 59444.2,
#  (13, 3): 121717.1,
#  (13, 4): 87498.5,
#  (13, 5): 75126.1,
#  (13, 6): 34411.5,
#  (13, 7): 67576.7,
#  (13, 8): 99214.5,
#  (13, 9): 65300.5,
#  (13, 10): 31026.0,
#  (13, 11): 48055.0,
#  (13, 12): 52714.9,
#  (13, 13): 0.0}

# %%
tauDistDF = vrv.convertMatricesDictionaryToDataframe(tauDist)
tauDistDF
# Out:
#           1         2         3         4         5         6         7   \
# 1        0.0   87311.2   84438.6   47288.3  114146.5   73431.9  106354.8
# 2    90218.4       0.0  132001.3  117734.1   46215.3   28344.3   64490.9
# 3    84438.6  131789.2       0.0   64897.5  130968.4  109205.5  101080.8
# 4    47288.3  117522.0   64897.5       0.0  116701.2   94938.3   86813.6
# 5   114091.8   46215.3  130968.4  116701.2       0.0   54238.6   44057.0
# 6    73377.2   29748.8  109205.5   94938.3   54238.6       0.0   46689.2
# 7   106542.4   64278.8  101080.8   86813.6   44057.0   46689.2       0.0
# 8    71374.4  124913.5   34893.3   31955.8  124092.6  102329.7   94205.1
# 9    74049.8  130231.7  114357.1   73650.2  139198.8   98484.2  131649.4
# 10   27984.0   79319.0  106392.3   72173.7  106154.3   65439.6   98604.9
# 11   40382.8   49751.2   84489.4   70222.2   48930.4   27167.5   33911.2
# 12   93639.7   56942.2  157656.8  140720.4  102689.9   61975.3   95140.5
# 13   39018.2   59444.2  121717.1   87498.5   75126.1   34411.5   67576.7
#
#           8         9         10        11        12        13
# 1    71374.4   75239.6   27984.0   40382.8   93688.7   39058.5
# 2   125125.6  129457.2   82226.1   49963.3   49618.9   62375.7
# 3    34893.3  115460.0  106392.3   84489.4  157676.3  130093.0
# 4    31955.8   74774.5   72369.3   70222.2  141662.3   87734.4
# 5   124092.6  140374.1  106099.6   48930.4   85137.3   75126.1
# 6   102329.7   99659.5   65384.9   27167.5   61994.8   34411.5
# 7    94205.1  132824.7   98550.2   33911.2   95160.0   67576.7
# 8        0.0   86469.1   84064.0   77613.7  153357.0   99429.1
# 9    85366.3       0.0   57449.5  112127.7   87316.0   64110.8
# 10   83889.7   56563.7       0.0   79083.1   80379.2   31066.2
# 11   77613.7  113303.0   79028.4       0.0   75638.3   48055.0
# 12  152436.4   88765.6   85647.5   75618.8       0.0   52734.4
# 13   99214.5   65300.5   31026.0   48055.0   52714.9       0.0

# %% [markdown]
# ## Export as .csv File

# %%
vrv.exportDataframe(nodes, 'nodes.csv')
# Out:
# Message: Data written to nodes.csv.

# %%
vrv.exportDataToCSV(tauTime, 'tauTime.csv')
vrv.exportDataToCSV(tauDist, 'tauDist.csv')
# Out:
# Message: Data written to tauTime.csv.
# Message: Data written to tauDist.csv.

# %% [markdown]
# ## Fitting into (Your) External Solver

# %% [markdown]
# - Notice: External Solver is not included in this package, here we plug in the solver that user is developing for their research.

# %%
import TSPSolver
nodes = vrv.importDataFromCSV('nodes', 'nodes.csv')
tauDist = vrv.importDataFromCSV('matrix', 'tauDist.csv')
tauTime = vrv.importDataFromCSV('matrix', 'tauTime.csv')

# %% [markdown]
# - Node structure for TSPSolver
#
# ```python
# class CNode:
#     def __init__(self, nodeID, nodeType, lat, lon):
#         self.nodeID = nodeID
#         self.nodeType = nodeType
#         self.lat = lat
#         self.lon = lon
# ```

# %%
n = []
for i in range(len(nodes)):
    n.append(TSPSolver.CNode(
        nodes.iloc[i]['id'],
        nodes.iloc[i]['nodeType'],
        nodes.iloc[i]['lat'],
        nodes.iloc[i]['lon']
    ))

# %%
seq = TSPSolver.TSPSolver(n, tauDist)
# Out:
# Academic license - for non-commercial use only
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 26 rows, 156 columns and 312 nonzeros
# Variable types: 0 continuous, 156 integer (156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 26 rows, 156 columns, 312 nonzeros
# Variable types: 0 continuous, 156 integer (156 binary)
#
# Root relaxation: objective 5.694484e+05, 33 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 569448.400    0   10          - 569448.400      -     -    0s
# H    0     0                    699849.70000 569448.400  18.6%     -    0s
# *    0     0               0    608135.10000 608135.100  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Lazy constraints: 21
#
# Explored 1 nodes (51 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 608135 699850
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.081351000000e+05, best bound 6.081351000000e+05, gap 0.0000%

# %%
seq
# Out:
# [1, 10, 13, 6, 11, 7, 5, 2, 12, 9, 4, 8, 3, 1]

# %% [markdown]
# ## Process Routing Results

# %% [markdown]
# - Build Arc Dataframe

# %%
arcs = vrv.createArcsFromNodeSeq(
    nodeSeq = seq,
    nodes=nodes)

# %%
arcs
# Out:
#    odID objectID   startLat   startLon     endLat     endLon leafletColor  \
# 0     1     None  41.500000 -77.500000  41.540730 -77.359086       orange
# 1     2     None  41.540730 -77.359086  41.638532 -77.340577       orange
# 2     3     None  41.638532 -77.340577  41.784584 -77.548038       orange
# 3     4     None  41.784584 -77.548038  41.667345 -77.676581       orange
# 4     5     None  41.667345 -77.676581  41.713083 -77.866776       orange
# 5     6     None  41.713083 -77.866776  41.958312 -77.881078       orange
# 6     7     None  41.958312 -77.881078  41.974404 -77.530365       orange
# 7     8     None  41.974404 -77.530365  41.953599 -77.066891       orange
# 8     9     None  41.953599 -77.066891  41.457648 -77.018324       orange
# 9    10     None  41.457648 -77.018324  41.230588 -77.431782       orange
# 10   11     None  41.230588 -77.431782  41.209624 -77.566319       orange
# 11   12     None  41.209624 -77.566319  41.213616 -77.824253       orange
# 12   13     None  41.213616 -77.824253  41.500000 -77.500000       orange
#
#    leafletWeight leafletStyle  leafletOpacity leafletCurveType  \
# 0              3        solid             0.8         straight
# 1              3        solid             0.8         straight
# 2              3        solid             0.8         straight
# 3              3        solid             0.8         straight
# 4              3        solid             0.8         straight
# 5              3        solid             0.8         straight
# 6              3        solid             0.8         straight
# 7              3        solid             0.8         straight
# 8              3        solid             0.8         straight
# 9              3        solid             0.8         straight
# 10             3        solid             0.8         straight
# 11             3        solid             0.8         straight
# 12             3        solid             0.8         straight
#
#    leafletCurvature useArrows cesiumColor cesiumWeight cesiumStyle  \
# 0                 0      True      orange            3       solid
# 1                 0      True      orange            3       solid
# 2                 0      True      orange            3       solid
# 3                 0      True      orange            3       solid
# 4                 0      True      orange            3       solid
# 5                 0      True      orange            3       solid
# 6                 0      True      orange            3       solid
# 7                 0      True      orange            3       solid
# 8                 0      True      orange            3       solid
# 9                 0      True      orange            3       solid
# 10                0      True      orange            3       solid
# 11                0      True      orange            3       solid
# 12                0      True      orange            3       solid
#
#     cesiumOpacity popupText startElevMeters endElevMeters
# 0             0.8      None            None          None
# 1             0.8      None            None          None
# 2             0.8      None            None          None
# 3             0.8      None            None          None
# 4             0.8      None            None          None
# 5             0.8      None            None          None
# 6             0.8      None            None          None
# 7             0.8      None            None          None
# 8             0.8      None            None          None
# 9             0.8      None            None          None
# 10            0.8      None            None          None
# 11            0.8      None            None          None
# 12            0.8      None            None          None

# %%
vrv.createLeaflet(arcs=arcs, nodes=nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Build Assignments Dataframe

# %%
route = vrv.createAssignmentsFromNodeSeq2D(
    nodeSeq=seq, 
    nodes=nodes, 
    expDurationArgs = {
        'timeSecDict' : tauTime
    },
    routeType='fastest', 
    dataProvider='osrm-online')
# Out:
# Warning: `objectID` is None; the Assignments dataframe can not be visualized by Cesium.
# Warning: `modelFile` is None; the Assignments dataframe can not be visualized by Cesium.
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
#
# Message: The origin point (lat: 41.5, lon: -77.5) is 1416.6 meters away from the road. You might find a gap between the origin point and the route.
# Message: The destination point (lat: 41.5, lon: -77.5) is 1416.6 meters away from the road. You might find a gap between destination point and the route.

# %%
route
# Out:
#     odID objectID modelFile modelScale modelMinPxSize  startTimeSec  \
# 0      1     None      None        100             75      0.000000
# 1      1     None      None        100             75    245.323155
# 2      1     None      None        100             75    333.440480
# 3      1     None      None        100             75    378.232524
# 4      1     None      None        100             75    385.296817
# 5      1     None      None        100             75    401.824812
# 6      1     None      None        100             75    434.504300
# 7      1     None      None        100             75    475.232560
# 8      1     None      None        100             75    487.178308
# 9      1     None      None        100             75    503.878671
# 10     1     None      None        100             75    559.109073
# 11     1     None      None        100             75    594.622093
# 12     1     None      None        100             75    632.994380
# 13     1     None      None        100             75    747.964503
# 14     1     None      None        100             75    926.175155
# 15     1     None      None        100             75   1023.522612
# 16     1     None      None        100             75   1033.981132
# 17     1     None      None        100             75   1191.074442
# 18     1     None      None        100             75   1288.059203
# 19     1     None      None        100             75   1293.476069
# 20     1     None      None        100             75   1303.483130
# 21     1     None      None        100             75   1328.785291
# 22     1     None      None        100             75   1415.473181
# 23     1     None      None        100             75   1469.692567
# 24     1     None      None        100             75   1639.424735
# 25     1     None      None        100             75   1695.751915
# 26     1     None      None        100             75   1977.675373
# 27     1     None      None        100             75   2031.855353
# 28     2     None      None        100             75   2353.500000
# 29     2     None      None        100             75   2683.327146
# ..   ...      ...       ...        ...            ...           ...
# 820   13     None      None        100             75  36714.089591
# 821   13     None      None        100             75  36715.521659
# 822   13     None      None        100             75  36717.837955
# 823   13     None      None        100             75  36734.521510
# 824   13     None      None        100             75  36776.112189
# 825   13     None      None        100             75  36797.168450
# 826   13     None      None        100             75  36882.752671
# 827   13     None      None        100             75  36904.315830
# 828   13     None      None        100             75  36914.395290
# 829   13     None      None        100             75  36938.584752
# 830   13     None      None        100             75  36938.767885
# 831   13     None      None        100             75  37040.011222
# 832   13     None      None        100             75  37097.240268
# 833   13     None      None        100             75  37104.289558
# 834   13     None      None        100             75  37245.302453
# 835   13     None      None        100             75  37255.786059
# 836   13     None      None        100             75  37279.663550
# 837   13     None      None        100             75  37315.856249
# 838   13     None      None        100             75  37348.217023
# 839   13     None      None        100             75  37354.249344
# 840   13     None      None        100             75  37426.181824
# 841   13     None      None        100             75  37513.359165
# 842   13     None      None        100             75  37525.836305
# 843   13     None      None        100             75  37534.284326
# 844   13     None      None        100             75  37545.980534
# 845   13     None      None        100             75  37578.106440
# 846   13     None      None        100             75  37598.701834
# 847   13     None      None        100             75  37624.868407
# 848   13     None      None        100             75  37640.167968
# 849   13     None      None        100             75  37644.878241
#
#       startLat   startLon startAltMeters    endTimeSec  ...  ganttColor  \
# 0    41.488336 -77.493134              0    245.323155  ...    darkgray
# 1    41.505557 -77.472304              0    333.440480  ...    darkgray
# 2    41.506710 -77.461288              0    378.232524  ...    darkgray
# 3    41.508893 -77.456437              0    385.296817  ...    darkgray
# 4    41.509420 -77.455886              0    401.824812  ...    darkgray
# 5    41.510549 -77.454438              0    434.504300  ...    darkgray
# 6    41.512903 -77.451753              0    475.232560  ...    darkgray
# 7    41.516545 -77.450034              0    487.178308  ...    darkgray
# 8    41.517613 -77.449529              0    503.878671  ...    darkgray
# 9    41.519185 -77.449264              0    559.109073  ...    darkgray
# 10   41.524423 -77.449474              0    594.622093  ...    darkgray
# 11   41.527675 -77.448300              0    632.994380  ...    darkgray
# 12   41.529319 -77.443977              0    747.964503  ...    darkgray
# 13   41.523150 -77.432005              0    926.175155  ...    darkgray
# 14   41.536007 -77.417390              0   1023.522612  ...    darkgray
# 15   41.540271 -77.406485              0   1033.981132  ...    darkgray
# 16   41.540781 -77.405352              0   1191.074442  ...    darkgray
# 17   41.548709 -77.388551              0   1288.059203  ...    darkgray
# 18   41.556507 -77.382047              0   1293.476069  ...    darkgray
# 19   41.556366 -77.381389              0   1303.483130  ...    darkgray
# 20   41.556104 -77.380174              0   1328.785291  ...    darkgray
# 21   41.556548 -77.377033              0   1415.473181  ...    darkgray
# 22   41.561138 -77.367946              0   1469.692567  ...    darkgray
# 23   41.560305 -77.361187              0   1639.424735  ...    darkgray
# 24   41.549354 -77.345467              0   1695.751915  ...    darkgray
# 25   41.544025 -77.344927              0   1977.675373  ...    darkgray
# 26   41.524534 -77.320545              0   2031.855353  ...    darkgray
# 27   41.522305 -77.326709              0   2353.500000  ...    darkgray
# 28   41.540730 -77.359086              0   2683.327146  ...    darkgray
# 29   41.522305 -77.326709              0   2738.885440  ...    darkgray
# ..         ...        ...            ...           ...  ...         ...
# 820  41.380722 -77.440114              0  36715.521659  ...    darkgray
# 821  41.380898 -77.440264              0  36717.837955  ...    darkgray
# 822  41.381182 -77.440508              0  36734.521510  ...    darkgray
# 823  41.383215 -77.442291              0  36776.112189  ...    darkgray
# 824  41.386114 -77.449378              0  36797.168450  ...    darkgray
# 825  41.387000 -77.453288              0  36882.752671  ...    darkgray
# 826  41.399290 -77.456309              0  36904.315830  ...    darkgray
# 827  41.401514 -77.459270              0  36914.395290  ...    darkgray
# 828  41.402383 -77.460848              0  36938.584752  ...    darkgray
# 829  41.404528 -77.464576              0  36938.767885  ...    darkgray
# 830  41.404547 -77.464601              0  37040.011222  ...    darkgray
# 831  41.415567 -77.477695              0  37097.240268  ...    darkgray
# 832  41.419930 -77.487165              0  37104.289558  ...    darkgray
# 833  41.420655 -77.488136              0  37245.302453  ...    darkgray
# 834  41.437184 -77.504457              0  37255.786059  ...    darkgray
# 835  41.437657 -77.506392              0  37279.663550  ...    darkgray
# 836  41.439213 -77.510539              0  37315.856249  ...    darkgray
# 837  41.442809 -77.515687              0  37348.217023  ...    darkgray
# 838  41.447371 -77.517327              0  37354.249344  ...    darkgray
# 839  41.448244 -77.517170              0  37426.181824  ...    darkgray
# 840  41.457221 -77.509918              0  37513.359165  ...    darkgray
# 841  41.468012 -77.500937              0  37525.836305  ...    darkgray
# 842  41.469803 -77.500491              0  37534.284326  ...    darkgray
# 843  41.470994 -77.500919              0  37545.980534  ...    darkgray
# 844  41.472627 -77.501585              0  37578.106440  ...    darkgray
# 845  41.477310 -77.501963              0  37598.701834  ...    darkgray
# 846  41.480133 -77.500583              0  37624.868407  ...    darkgray
# 847  41.483462 -77.498088              0  37640.167968  ...    darkgray
# 848  41.485309 -77.496416              0  37644.878241  ...    darkgray
# 849  41.485928 -77.496815              0  37670.000000  ...    darkgray
#
#      popupText startElevMeters endElevMeters wayname waycategory  surface  \
# 0         None            None          None    None        None     None
# 1         None            None          None    None        None     None
# 2         None            None          None    None        None     None
# 3         None            None          None    None        None     None
# 4         None            None          None    None        None     None
# 5         None            None          None    None        None     None
# 6         None            None          None    None        None     None
# 7         None            None          None    None        None     None
# 8         None            None          None    None        None     None
# 9         None            None          None    None        None     None
# 10        None            None          None    None        None     None
# 11        None            None          None    None        None     None
# 12        None            None          None    None        None     None
# 13        None            None          None    None        None     None
# 14        None            None          None    None        None     None
# 15        None            None          None    None        None     None
# 16        None            None          None    None        None     None
# 17        None            None          None    None        None     None
# 18        None            None          None    None        None     None
# 19        None            None          None    None        None     None
# 20        None            None          None    None        None     None
# 21        None            None          None    None        None     None
# 22        None            None          None    None        None     None
# 23        None            None          None    None        None     None
# 24        None            None          None    None        None     None
# 25        None            None          None    None        None     None
# 26        None            None          None    None        None     None
# 27        None            None          None    None        None     None
# 28        None            None          None    None        None     None
# 29        None            None          None    None        None     None
# ..         ...             ...           ...     ...         ...      ...
# 820       None            None          None    None        None     None
# 821       None            None          None    None        None     None
# 822       None            None          None    None        None     None
# 823       None            None          None    None        None     None
# 824       None            None          None    None        None     None
# 825       None            None          None    None        None     None
# 826       None            None          None    None        None     None
# 827       None            None          None    None        None     None
# 828       None            None          None    None        None     None
# 829       None            None          None    None        None     None
# 830       None            None          None    None        None     None
# 831       None            None          None    None        None     None
# 832       None            None          None    None        None     None
# 833       None            None          None    None        None     None
# 834       None            None          None    None        None     None
# 835       None            None          None    None        None     None
# 836       None            None          None    None        None     None
# 837       None            None          None    None        None     None
# 838       None            None          None    None        None     None
# 839       None            None          None    None        None     None
# 840       None            None          None    None        None     None
# 841       None            None          None    None        None     None
# 842       None            None          None    None        None     None
# 843       None            None          None    None        None     None
# 844       None            None          None    None        None     None
# 845       None            None          None    None        None     None
# 846       None            None          None    None        None     None
# 847       None            None          None    None        None     None
# 848       None            None          None    None        None     None
# 849       None            None          None    None        None     None
#
#     waytype steepness tollway
# 0      None      None    None
# 1      None      None    None
# 2      None      None    None
# 3      None      None    None
# 4      None      None    None
# 5      None      None    None
# 6      None      None    None
# 7      None      None    None
# 8      None      None    None
# 9      None      None    None
# 10     None      None    None
# 11     None      None    None
# 12     None      None    None
# 13     None      None    None
# 14     None      None    None
# 15     None      None    None
# 16     None      None    None
# 17     None      None    None
# 18     None      None    None
# 19     None      None    None
# 20     None      None    None
# 21     None      None    None
# 22     None      None    None
# 23     None      None    None
# 24     None      None    None
# 25     None      None    None
# 26     None      None    None
# 27     None      None    None
# 28     None      None    None
# 29     None      None    None
# ..      ...       ...     ...
# 820    None      None    None
# 821    None      None    None
# 822    None      None    None
# 823    None      None    None
# 824    None      None    None
# 825    None      None    None
# 826    None      None    None
# 827    None      None    None
# 828    None      None    None
# 829    None      None    None
# 830    None      None    None
# 831    None      None    None
# 832    None      None    None
# 833    None      None    None
# 834    None      None    None
# 835    None      None    None
# 836    None      None    None
# 837    None      None    None
# 838    None      None    None
# 839    None      None    None
# 840    None      None    None
# 841    None      None    None
# 842    None      None    None
# 843    None      None    None
# 844    None      None    None
# 845    None      None    None
# 846    None      None    None
# 847    None      None    None
# 848    None      None    None
# 849    None      None    None
#
# [850 rows x 34 columns]

# %%
vrv.createLeaflet(
    arcs = route, 
    nodes = nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Add 3d model into assignments dataframe

# %%
route['objectID'] = 1
route['modelFile'] = '/veroviz/models/ub_truck.gltf'
route
# Out:
#     odID  objectID                      modelFile modelScale modelMinPxSize  \
# 0      1         1  /veroviz/models/ub_truck.gltf        100             75
# 1      1         1  /veroviz/models/ub_truck.gltf        100             75
# 2      1         1  /veroviz/models/ub_truck.gltf        100             75
# 3      1         1  /veroviz/models/ub_truck.gltf        100             75
# 4      1         1  /veroviz/models/ub_truck.gltf        100             75
# 5      1         1  /veroviz/models/ub_truck.gltf        100             75
# 6      1         1  /veroviz/models/ub_truck.gltf        100             75
# 7      1         1  /veroviz/models/ub_truck.gltf        100             75
# 8      1         1  /veroviz/models/ub_truck.gltf        100             75
# 9      1         1  /veroviz/models/ub_truck.gltf        100             75
# 10     1         1  /veroviz/models/ub_truck.gltf        100             75
# 11     1         1  /veroviz/models/ub_truck.gltf        100             75
# 12     1         1  /veroviz/models/ub_truck.gltf        100             75
# 13     1         1  /veroviz/models/ub_truck.gltf        100             75
# 14     1         1  /veroviz/models/ub_truck.gltf        100             75
# 15     1         1  /veroviz/models/ub_truck.gltf        100             75
# 16     1         1  /veroviz/models/ub_truck.gltf        100             75
# 17     1         1  /veroviz/models/ub_truck.gltf        100             75
# 18     1         1  /veroviz/models/ub_truck.gltf        100             75
# 19     1         1  /veroviz/models/ub_truck.gltf        100             75
# 20     1         1  /veroviz/models/ub_truck.gltf        100             75
# 21     1         1  /veroviz/models/ub_truck.gltf        100             75
# 22     1         1  /veroviz/models/ub_truck.gltf        100             75
# 23     1         1  /veroviz/models/ub_truck.gltf        100             75
# 24     1         1  /veroviz/models/ub_truck.gltf        100             75
# 25     1         1  /veroviz/models/ub_truck.gltf        100             75
# 26     1         1  /veroviz/models/ub_truck.gltf        100             75
# 27     1         1  /veroviz/models/ub_truck.gltf        100             75
# 28     2         1  /veroviz/models/ub_truck.gltf        100             75
# 29     2         1  /veroviz/models/ub_truck.gltf        100             75
# ..   ...       ...                            ...        ...            ...
# 820   13         1  /veroviz/models/ub_truck.gltf        100             75
# 821   13         1  /veroviz/models/ub_truck.gltf        100             75
# 822   13         1  /veroviz/models/ub_truck.gltf        100             75
# 823   13         1  /veroviz/models/ub_truck.gltf        100             75
# 824   13         1  /veroviz/models/ub_truck.gltf        100             75
# 825   13         1  /veroviz/models/ub_truck.gltf        100             75
# 826   13         1  /veroviz/models/ub_truck.gltf        100             75
# 827   13         1  /veroviz/models/ub_truck.gltf        100             75
# 828   13         1  /veroviz/models/ub_truck.gltf        100             75
# 829   13         1  /veroviz/models/ub_truck.gltf        100             75
# 830   13         1  /veroviz/models/ub_truck.gltf        100             75
# 831   13         1  /veroviz/models/ub_truck.gltf        100             75
# 832   13         1  /veroviz/models/ub_truck.gltf        100             75
# 833   13         1  /veroviz/models/ub_truck.gltf        100             75
# 834   13         1  /veroviz/models/ub_truck.gltf        100             75
# 835   13         1  /veroviz/models/ub_truck.gltf        100             75
# 836   13         1  /veroviz/models/ub_truck.gltf        100             75
# 837   13         1  /veroviz/models/ub_truck.gltf        100             75
# 838   13         1  /veroviz/models/ub_truck.gltf        100             75
# 839   13         1  /veroviz/models/ub_truck.gltf        100             75
# 840   13         1  /veroviz/models/ub_truck.gltf        100             75
# 841   13         1  /veroviz/models/ub_truck.gltf        100             75
# 842   13         1  /veroviz/models/ub_truck.gltf        100             75
# 843   13         1  /veroviz/models/ub_truck.gltf        100             75
# 844   13         1  /veroviz/models/ub_truck.gltf        100             75
# 845   13         1  /veroviz/models/ub_truck.gltf        100             75
# 846   13         1  /veroviz/models/ub_truck.gltf        100             75
# 847   13         1  /veroviz/models/ub_truck.gltf        100             75
# 848   13         1  /veroviz/models/ub_truck.gltf        100             75
# 849   13         1  /veroviz/models/ub_truck.gltf        100             75
#
#      startTimeSec   startLat   startLon startAltMeters    endTimeSec  ...  \
# 0        0.000000  41.488336 -77.493134              0    245.323155  ...
# 1      245.323155  41.505557 -77.472304              0    333.440480  ...
# 2      333.440480  41.506710 -77.461288              0    378.232524  ...
# 3      378.232524  41.508893 -77.456437              0    385.296817  ...
# 4      385.296817  41.509420 -77.455886              0    401.824812  ...
# 5      401.824812  41.510549 -77.454438              0    434.504300  ...
# 6      434.504300  41.512903 -77.451753              0    475.232560  ...
# 7      475.232560  41.516545 -77.450034              0    487.178308  ...
# 8      487.178308  41.517613 -77.449529              0    503.878671  ...
# 9      503.878671  41.519185 -77.449264              0    559.109073  ...
# 10     559.109073  41.524423 -77.449474              0    594.622093  ...
# 11     594.622093  41.527675 -77.448300              0    632.994380  ...
# 12     632.994380  41.529319 -77.443977              0    747.964503  ...
# 13     747.964503  41.523150 -77.432005              0    926.175155  ...
# 14     926.175155  41.536007 -77.417390              0   1023.522612  ...
# 15    1023.522612  41.540271 -77.406485              0   1033.981132  ...
# 16    1033.981132  41.540781 -77.405352              0   1191.074442  ...
# 17    1191.074442  41.548709 -77.388551              0   1288.059203  ...
# 18    1288.059203  41.556507 -77.382047              0   1293.476069  ...
# 19    1293.476069  41.556366 -77.381389              0   1303.483130  ...
# 20    1303.483130  41.556104 -77.380174              0   1328.785291  ...
# 21    1328.785291  41.556548 -77.377033              0   1415.473181  ...
# 22    1415.473181  41.561138 -77.367946              0   1469.692567  ...
# 23    1469.692567  41.560305 -77.361187              0   1639.424735  ...
# 24    1639.424735  41.549354 -77.345467              0   1695.751915  ...
# 25    1695.751915  41.544025 -77.344927              0   1977.675373  ...
# 26    1977.675373  41.524534 -77.320545              0   2031.855353  ...
# 27    2031.855353  41.522305 -77.326709              0   2353.500000  ...
# 28    2353.500000  41.540730 -77.359086              0   2683.327146  ...
# 29    2683.327146  41.522305 -77.326709              0   2738.885440  ...
# ..            ...        ...        ...            ...           ...  ...
# 820  36714.089591  41.380722 -77.440114              0  36715.521659  ...
# 821  36715.521659  41.380898 -77.440264              0  36717.837955  ...
# 822  36717.837955  41.381182 -77.440508              0  36734.521510  ...
# 823  36734.521510  41.383215 -77.442291              0  36776.112189  ...
# 824  36776.112189  41.386114 -77.449378              0  36797.168450  ...
# 825  36797.168450  41.387000 -77.453288              0  36882.752671  ...
# 826  36882.752671  41.399290 -77.456309              0  36904.315830  ...
# 827  36904.315830  41.401514 -77.459270              0  36914.395290  ...
# 828  36914.395290  41.402383 -77.460848              0  36938.584752  ...
# 829  36938.584752  41.404528 -77.464576              0  36938.767885  ...
# 830  36938.767885  41.404547 -77.464601              0  37040.011222  ...
# 831  37040.011222  41.415567 -77.477695              0  37097.240268  ...
# 832  37097.240268  41.419930 -77.487165              0  37104.289558  ...
# 833  37104.289558  41.420655 -77.488136              0  37245.302453  ...
# 834  37245.302453  41.437184 -77.504457              0  37255.786059  ...
# 835  37255.786059  41.437657 -77.506392              0  37279.663550  ...
# 836  37279.663550  41.439213 -77.510539              0  37315.856249  ...
# 837  37315.856249  41.442809 -77.515687              0  37348.217023  ...
# 838  37348.217023  41.447371 -77.517327              0  37354.249344  ...
# 839  37354.249344  41.448244 -77.517170              0  37426.181824  ...
# 840  37426.181824  41.457221 -77.509918              0  37513.359165  ...
# 841  37513.359165  41.468012 -77.500937              0  37525.836305  ...
# 842  37525.836305  41.469803 -77.500491              0  37534.284326  ...
# 843  37534.284326  41.470994 -77.500919              0  37545.980534  ...
# 844  37545.980534  41.472627 -77.501585              0  37578.106440  ...
# 845  37578.106440  41.477310 -77.501963              0  37598.701834  ...
# 846  37598.701834  41.480133 -77.500583              0  37624.868407  ...
# 847  37624.868407  41.483462 -77.498088              0  37640.167968  ...
# 848  37640.167968  41.485309 -77.496416              0  37644.878241  ...
# 849  37644.878241  41.485928 -77.496815              0  37670.000000  ...
#
#      ganttColor  popupText startElevMeters endElevMeters wayname waycategory  \
# 0      darkgray       None            None          None    None        None
# 1      darkgray       None            None          None    None        None
# 2      darkgray       None            None          None    None        None
# 3      darkgray       None            None          None    None        None
# 4      darkgray       None            None          None    None        None
# 5      darkgray       None            None          None    None        None
# 6      darkgray       None            None          None    None        None
# 7      darkgray       None            None          None    None        None
# 8      darkgray       None            None          None    None        None
# 9      darkgray       None            None          None    None        None
# 10     darkgray       None            None          None    None        None
# 11     darkgray       None            None          None    None        None
# 12     darkgray       None            None          None    None        None
# 13     darkgray       None            None          None    None        None
# 14     darkgray       None            None          None    None        None
# 15     darkgray       None            None          None    None        None
# 16     darkgray       None            None          None    None        None
# 17     darkgray       None            None          None    None        None
# 18     darkgray       None            None          None    None        None
# 19     darkgray       None            None          None    None        None
# 20     darkgray       None            None          None    None        None
# 21     darkgray       None            None          None    None        None
# 22     darkgray       None            None          None    None        None
# 23     darkgray       None            None          None    None        None
# 24     darkgray       None            None          None    None        None
# 25     darkgray       None            None          None    None        None
# 26     darkgray       None            None          None    None        None
# 27     darkgray       None            None          None    None        None
# 28     darkgray       None            None          None    None        None
# 29     darkgray       None            None          None    None        None
# ..          ...        ...             ...           ...     ...         ...
# 820    darkgray       None            None          None    None        None
# 821    darkgray       None            None          None    None        None
# 822    darkgray       None            None          None    None        None
# 823    darkgray       None            None          None    None        None
# 824    darkgray       None            None          None    None        None
# 825    darkgray       None            None          None    None        None
# 826    darkgray       None            None          None    None        None
# 827    darkgray       None            None          None    None        None
# 828    darkgray       None            None          None    None        None
# 829    darkgray       None            None          None    None        None
# 830    darkgray       None            None          None    None        None
# 831    darkgray       None            None          None    None        None
# 832    darkgray       None            None          None    None        None
# 833    darkgray       None            None          None    None        None
# 834    darkgray       None            None          None    None        None
# 835    darkgray       None            None          None    None        None
# 836    darkgray       None            None          None    None        None
# 837    darkgray       None            None          None    None        None
# 838    darkgray       None            None          None    None        None
# 839    darkgray       None            None          None    None        None
# 840    darkgray       None            None          None    None        None
# 841    darkgray       None            None          None    None        None
# 842    darkgray       None            None          None    None        None
# 843    darkgray       None            None          None    None        None
# 844    darkgray       None            None          None    None        None
# 845    darkgray       None            None          None    None        None
# 846    darkgray       None            None          None    None        None
# 847    darkgray       None            None          None    None        None
# 848    darkgray       None            None          None    None        None
# 849    darkgray       None            None          None    None        None
#
#      surface waytype steepness tollway
# 0       None    None      None    None
# 1       None    None      None    None
# 2       None    None      None    None
# 3       None    None      None    None
# 4       None    None      None    None
# 5       None    None      None    None
# 6       None    None      None    None
# 7       None    None      None    None
# 8       None    None      None    None
# 9       None    None      None    None
# 10      None    None      None    None
# 11      None    None      None    None
# 12      None    None      None    None
# 13      None    None      None    None
# 14      None    None      None    None
# 15      None    None      None    None
# 16      None    None      None    None
# 17      None    None      None    None
# 18      None    None      None    None
# 19      None    None      None    None
# 20      None    None      None    None
# 21      None    None      None    None
# 22      None    None      None    None
# 23      None    None      None    None
# 24      None    None      None    None
# 25      None    None      None    None
# 26      None    None      None    None
# 27      None    None      None    None
# 28      None    None      None    None
# 29      None    None      None    None
# ..       ...     ...       ...     ...
# 820     None    None      None    None
# 821     None    None      None    None
# 822     None    None      None    None
# 823     None    None      None    None
# 824     None    None      None    None
# 825     None    None      None    None
# 826     None    None      None    None
# 827     None    None      None    None
# 828     None    None      None    None
# 829     None    None      None    None
# 830     None    None      None    None
# 831     None    None      None    None
# 832     None    None      None    None
# 833     None    None      None    None
# 834     None    None      None    None
# 835     None    None      None    None
# 836     None    None      None    None
# 837     None    None      None    None
# 838     None    None      None    None
# 839     None    None      None    None
# 840     None    None      None    None
# 841     None    None      None    None
# 842     None    None      None    None
# 843     None    None      None    None
# 844     None    None      None    None
# 845     None    None      None    None
# 846     None    None      None    None
# 847     None    None      None    None
# 848     None    None      None    None
# 849     None    None      None    None
#
# [850 rows x 34 columns]

# %%
vrv.createCesium(
    nodes=nodes, 
    assignments=route,
    cesiumDir='D:/Cesium',
    problemDir='veroviz/demo'
)
# Out:
# Message: File selector was written to D:/Cesium/veroviz/demo/;veroviz;demo.vrv ...
# Message: Configs were written to D:/Cesium/veroviz/demo/config.js ...
# Message: Nodes were written to D:/Cesium/veroviz/demo/displayNodes.js ...
# Message: Assignments (.js) were written to D:/Cesium/veroviz/demo/displayPaths.js ...
# Message: Assignments (.czml) were written to D:/Cesium/veroviz/demo/routes.czml ...
