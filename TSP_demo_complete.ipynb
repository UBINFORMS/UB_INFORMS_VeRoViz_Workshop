# %% [markdown]
# # An Introduction to VeRoViz - TSP Demo

# %% [markdown]
# May 5th 2020
# - This workshop highlights basic functionality provided in version v0.4.0
# - Python version >= 3.7.2

# %% [markdown]
# ---

# %% [markdown]
# - Let's get started!

# %%
import veroviz as vrv
vrv.checkVersion()
# Out:
# 'Your current installed version of veroviz is 0.4.0. You are up-to-date with the latest available version.'

# %% [markdown]
# ## Generate Nodes

# %% [markdown]
# - Create a depot

# %%
nodes = vrv.createNodesFromLocs(
    locs = [[41.5, -77.5]],
    nodeType = 'Depot',
    leafletColor = 'red'
)

# %% [markdown]
# - Create Customers

# %%
boundingRegion = [[42, -78], [41, -78], [41, -77], [42, -77]]
nodes = vrv.generateNodes(
    initNodes = nodes,
    nodeType = 'Customer',
    numNodes = 12,
    nodeName = 'Customer',
    incrementName = True,
    incrementStart = 1,
    nodeDistrib = 'uniformBB',
    nodeDistribArgs = {
        'boundingRegion' : boundingRegion
    },
    leafletColor = 'green',
    snapToRoad=True,
    dataProvider='osrm-online'
)
nodes
# Out:
# Warning: 'id' in `initNodes` is already larger than `startNode`. Overriding `startNode` with maximum `id` + 1.
#     id        lat        lon altMeters    nodeName  nodeType popupText  \
# 0    1  41.500000 -77.500000         0        None     Depot         1
# 1    2  41.056348 -77.237906         0   Customer1  Customer         2
# 2    3  41.391310 -77.114275         0   Customer2  Customer         3
# 3    4  41.979934 -77.566735         0   Customer3  Customer         4
# 4    5  41.496765 -77.958127         0   Customer4  Customer         5
# 5    6  41.990585 -77.021575         0   Customer5  Customer         6
# 6    7  41.510352 -77.998732         0   Customer6  Customer         7
# 7    8  41.938037 -77.303876         0   Customer7  Customer         8
# 8    9  41.371614 -77.780410         0   Customer8  Customer         9
# 9   10  41.382004 -77.591294         0   Customer9  Customer        10
# 10  11  41.716013 -77.013073         0  Customer10  Customer        11
# 11  12  41.336521 -77.051863         0  Customer11  Customer        12
# 12  13  41.552584 -77.151014         0  Customer12  Customer        13
#
#    leafletIconPrefix leafletIconType leafletColor leafletIconText  \
# 0          glyphicon       info-sign          red               1
# 1          glyphicon       info-sign        green               2
# 2          glyphicon       info-sign        green               3
# 3          glyphicon       info-sign        green               4
# 4          glyphicon       info-sign        green               5
# 5          glyphicon       info-sign        green               6
# 6          glyphicon       info-sign        green               7
# 7          glyphicon       info-sign        green               8
# 8          glyphicon       info-sign        green               9
# 9          glyphicon       info-sign        green              10
# 10         glyphicon       info-sign        green              11
# 11         glyphicon       info-sign        green              12
# 12         glyphicon       info-sign        green              13
#
#    cesiumIconType cesiumColor cesiumIconText elevMeters
# 0             pin        blue              1       None
# 1             pin        blue              2       None
# 2             pin        blue              3       None
# 3             pin        blue              4       None
# 4             pin        blue              5       None
# 5             pin        blue              6       None
# 6             pin        blue              7       None
# 7             pin        blue              8       None
# 8             pin        blue              9       None
# 9             pin        blue             10       None
# 10            pin        blue             11       None
# 11            pin        blue             12       None
# 12            pin        blue             13       None

# %% [markdown]
# - Visualize the nodes we've just created

# %%
vrv.createLeaflet(nodes = nodes, boundingRegion = boundingRegion)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Build Travel Matrices

# %% [markdown]
# - Build Travel Matrices

# %%
travelMatrices = vrv.getTimeDist2D(
    nodes = nodes,
    matrixType = 'all2all',
    routeType = 'fastest',
    dataProvider='osrm-online'
)

# %%
tauTime = travelMatrices[0]
tauDist = travelMatrices[1]

# %% [markdown]
# - Time Matrix

# %%
tauTime
# Out:
# {(1, 1): 0.0,
#  (1, 2): 4005.9,
#  (1, 3): 4751.3,
#  (1, 4): 5457.7,
#  (1, 5): 8887.6,
#  (1, 6): 4878.7,
#  (1, 7): 7933.4,
#  (1, 8): 4459.3,
#  (1, 9): 4245.2,
#  (1, 10): 3295.4,
#  (1, 11): 3719.0,
#  (1, 12): 3957.3,
#  (1, 13): 2602.4,
#  (2, 1): 4125.7,
#  (2, 2): 0.0,
#  (2, 3): 3791.3,
#  (2, 4): 7585.1,
#  (2, 5): 9577.3,
#  (2, 6): 6016.6,
#  (2, 7): 8623.1,
#  (2, 8): 6586.7,
#  (2, 9): 5118.2,
#  (2, 10): 4707.6,
#  (2, 11): 4856.9,
#  (2, 12): 3026.3,
#  (2, 13): 4065.7,
#  (3, 1): 4563.4,
#  (3, 2): 3822.3,
#  (3, 3): 0.0,
#  (3, 4): 6372.2,
#  (3, 5): 10653.7,
#  (3, 6): 4494.3,
#  (3, 7): 9695.4,
#  (3, 8): 5398.7,
#  (3, 9): 6330.1,
#  (3, 10): 5380.3,
#  (3, 11): 3334.6,
#  (3, 12): 1678.1,
#  (3, 13): 2543.4,
#  (4, 1): 5155.5,
#  (4, 2): 7279.3,
#  (4, 3): 6482.5,
#  (4, 4): 0.0,
#  (4, 5): 7269.6,
#  (4, 6): 3089.4,
#  (4, 7): 6311.3,
#  (4, 8): 2010.4,
#  (4, 9): 6393.1,
#  (4, 10): 6003.4,
#  (4, 11): 4332.6,
#  (4, 12): 5688.5,
#  (4, 13): 4467.1,
#  (5, 1): 8793.4,
#  (5, 2): 9558.4,
#  (5, 3): 10692.3,
#  (5, 4): 7310.3,
#  (5, 5): 0.0,
#  (5, 6): 8370.4,
#  (5, 7): 1326.2,
#  (5, 8): 7901.4,
#  (5, 9): 5717.2,
#  (5, 10): 7138.6,
#  (5, 11): 8611.4,
#  (5, 12): 9898.3,
#  (5, 13): 8543.4,
#  (6, 1): 4917.5,
#  (6, 2): 6055.4,
#  (6, 3): 4765.4,
#  (6, 4): 3224.9,
#  (6, 5): 8511.1,
#  (6, 6): 0.0,
#  (6, 7): 7552.8,
#  (6, 8): 2251.4,
#  (6, 9): 7269.1,
#  (6, 10): 6879.4,
#  (6, 11): 2615.5,
#  (6, 12): 3971.4,
#  (6, 13): 2867.9,
#  (7, 1): 7875.7,
#  (7, 2): 8604.9,
#  (7, 3): 9736.9,
#  (7, 4): 6354.9,
#  (7, 5): 1326.4,
#  (7, 6): 7415.0,
#  (7, 7): 0.0,
#  (7, 8): 6946.0,
#  (7, 9): 4763.7,
#  (7, 10): 6183.2,
#  (7, 11): 7656.0,
#  (7, 12): 8942.9,
#  (7, 13): 7588.0,
#  (8, 1): 4307.9,
#  (8, 2): 6431.7,
#  (8, 3): 5573.4,
#  (8, 4): 2088.7,
#  (8, 5): 7916.7,
#  (8, 6): 2180.3,
#  (8, 7): 6958.4,
#  (8, 8): 0.0,
#  (8, 9): 6674.7,
#  (8, 10): 6285.0,
#  (8, 11): 3423.5,
#  (8, 12): 4779.4,
#  (8, 13): 3675.9,
#  (9, 1): 4945.0,
#  (9, 2): 5710.0,
#  (9, 3): 6958.7,
#  (9, 4): 7945.3,
#  (9, 5): 6600.7,
#  (9, 6): 8258.9,
#  (9, 7): 5646.5,
#  (9, 8): 7789.9,
#  (9, 9): 0.0,
#  (9, 10): 3384.8,
#  (9, 11): 7848.2,
#  (9, 12): 6199.5,
#  (9, 13): 7057.0,
#  (10, 1): 3254.7,
#  (10, 2): 4545.9,
#  (10, 3): 5268.4,
#  (10, 4): 6562.6,
#  (10, 5): 7315.2,
#  (10, 6): 6876.2,
#  (10, 7): 6361.0,
#  (10, 8): 6407.2,
#  (10, 9): 2672.8,
#  (10, 10): 0.0,
#  (10, 11): 6157.9,
#  (10, 12): 4696.4,
#  (10, 13): 5366.7,
#  (11, 1): 3651.9,
#  (11, 2): 4789.8,
#  (11, 3): 3499.8,
#  (11, 4): 4408.3,
#  (11, 5): 8659.8,
#  (11, 6): 2530.4,
#  (11, 7): 7701.5,
#  (11, 8): 3434.8,
#  (11, 9): 7086.2,
#  (11, 10): 6136.4,
#  (11, 11): 0.0,
#  (11, 12): 2705.8,
#  (11, 13): 1602.3,
#  (12, 1): 3903.8,
#  (12, 2): 2889.3,
#  (12, 3): 1536.6,
#  (12, 4): 5712.6,
#  (12, 5): 10005.4,
#  (12, 6): 3834.7,
#  (12, 7): 9035.8,
#  (12, 8): 4739.1,
#  (12, 9): 5363.0,
#  (12, 10): 4671.7,
#  (12, 11): 2675.0,
#  (12, 12): 0.0,
#  (12, 13): 1883.8,
#  (13, 1): 2658.0,
#  (13, 2): 3950.1,
#  (13, 3): 2660.1,
#  (13, 4): 4694.2,
#  (13, 5): 8748.3,
#  (13, 6): 2816.3,
#  (13, 7): 7790.0,
#  (13, 8): 3720.7,
#  (13, 9): 6246.5,
#  (13, 10): 5296.7,
#  (13, 11): 1656.6,
#  (13, 12): 1866.1,
#  (13, 13): 0.0}

# %%
tauTimeDF = vrv.convertMatricesDictionaryToDataframe(tauTime)
tauTimeDF
# Out:
#         1       2        3       4        5       6       7       8       9   \
# 1      0.0  4005.9   4751.3  5457.7   8887.6  4878.7  7933.4  4459.3  4245.2
# 2   4125.7     0.0   3791.3  7585.1   9577.3  6016.6  8623.1  6586.7  5118.2
# 3   4563.4  3822.3      0.0  6372.2  10653.7  4494.3  9695.4  5398.7  6330.1
# 4   5155.5  7279.3   6482.5     0.0   7269.6  3089.4  6311.3  2010.4  6393.1
# 5   8793.4  9558.4  10692.3  7310.3      0.0  8370.4  1326.2  7901.4  5717.2
# 6   4917.5  6055.4   4765.4  3224.9   8511.1     0.0  7552.8  2251.4  7269.1
# 7   7875.7  8604.9   9736.9  6354.9   1326.4  7415.0     0.0  6946.0  4763.7
# 8   4307.9  6431.7   5573.4  2088.7   7916.7  2180.3  6958.4     0.0  6674.7
# 9   4945.0  5710.0   6958.7  7945.3   6600.7  8258.9  5646.5  7789.9     0.0
# 10  3254.7  4545.9   5268.4  6562.6   7315.2  6876.2  6361.0  6407.2  2672.8
# 11  3651.9  4789.8   3499.8  4408.3   8659.8  2530.4  7701.5  3434.8  7086.2
# 12  3903.8  2889.3   1536.6  5712.6  10005.4  3834.7  9035.8  4739.1  5363.0
# 13  2658.0  3950.1   2660.1  4694.2   8748.3  2816.3  7790.0  3720.7  6246.5
#
#         10      11      12      13
# 1   3295.4  3719.0  3957.3  2602.4
# 2   4707.6  4856.9  3026.3  4065.7
# 3   5380.3  3334.6  1678.1  2543.4
# 4   6003.4  4332.6  5688.5  4467.1
# 5   7138.6  8611.4  9898.3  8543.4
# 6   6879.4  2615.5  3971.4  2867.9
# 7   6183.2  7656.0  8942.9  7588.0
# 8   6285.0  3423.5  4779.4  3675.9
# 9   3384.8  7848.2  6199.5  7057.0
# 10     0.0  6157.9  4696.4  5366.7
# 11  6136.4     0.0  2705.8  1602.3
# 12  4671.7  2675.0     0.0  1883.8
# 13  5296.7  1656.6  1866.1     0.0

# %% [markdown]
# - Distance Matrix

# %%
tauDist
# Out:
# {(1, 1): 0.0,
#  (1, 2): 71329.5,
#  (1, 3): 83725.1,
#  (1, 4): 97658.2,
#  (1, 5): 138436.6,
#  (1, 6): 99732.5,
#  (1, 7): 135338.0,
#  (1, 8): 69402.2,
#  (1, 9): 71064.7,
#  (1, 10): 51821.7,
#  (1, 11): 62447.6,
#  (1, 12): 77225.8,
#  (1, 13): 40633.6,
#  (2, 1): 71845.8,
#  (2, 2): 0.0,
#  (2, 3): 54028.0,
#  (2, 4): 143673.7,
#  (2, 5): 168299.2,
#  (2, 6): 145045.6,
#  (2, 7): 165200.7,
#  (2, 8): 115417.6,
#  (2, 9): 93275.8,
#  (2, 10): 73844.8,
#  (2, 11): 107760.7,
#  (2, 12): 56847.2,
#  (2, 13): 90826.1,
#  (3, 1): 78183.2,
#  (3, 2): 54267.9,
#  (3, 3): 0.0,
#  (3, 4): 133761.7,
#  (3, 5): 182662.2,
#  (3, 6): 97493.1,
#  (3, 7): 179644.5,
#  (3, 8): 108959.5,
#  (3, 9): 91591.0,
#  (3, 10): 72348.0,
#  (3, 11): 60208.3,
#  (3, 12): 16441.4,
#  (3, 13): 43273.7,
#  (4, 1): 91015.1,
#  (4, 2): 137270.5,
#  (4, 3): 139294.0,
#  (4, 4): 0.0,
#  (4, 5): 102313.6,
#  (4, 6): 54779.7,
#  (4, 7): 99296.0,
#  (4, 8): 28461.0,
#  (4, 9): 110694.2,
#  (4, 10): 95616.0,
#  (4, 11): 83725.9,
#  (4, 12): 132794.7,
#  (4, 13): 82691.5,
#  (5, 1): 138436.6,
#  (5, 2): 161683.5,
#  (5, 3): 164355.5,
#  (5, 4): 100300.7,
#  (5, 5): 0.0,
#  (5, 6): 124248.9,
#  (5, 7): 7130.4,
#  (5, 8): 107025.4,
#  (5, 9): 78869.1,
#  (5, 10): 86092.3,
#  (5, 11): 119409.2,
#  (5, 12): 157856.2,
#  (5, 13): 121264.0,
#  (6, 1): 99683.5,
#  (6, 2): 144539.3,
#  (6, 3): 103295.0,
#  (6, 4): 54779.7,
#  (6, 5): 148063.6,
#  (6, 6): 0.0,
#  (6, 7): 145046.0,
#  (6, 8): 29977.5,
#  (6, 9): 142175.6,
#  (6, 10): 127097.4,
#  (6, 11): 47726.9,
#  (6, 12): 96795.7,
#  (6, 13): 63953.8,
#  (7, 1): 124951.7,
#  (7, 2): 158585.0,
#  (7, 3): 161337.9,
#  (7, 4): 97283.1,
#  (7, 5): 7130.4,
#  (7, 6): 121231.3,
#  (7, 7): 0.0,
#  (7, 8): 104007.8,
#  (7, 9): 75770.6,
#  (7, 10): 83074.6,
#  (7, 11): 116391.5,
#  (7, 12): 154838.6,
#  (7, 13): 118246.4,
#  (8, 1): 69397.3,
#  (8, 2): 115652.7,
#  (8, 3): 114491.7,
#  (8, 4): 28461.0,
#  (8, 5): 130840.1,
#  (8, 6): 29977.5,
#  (8, 7): 127822.5,
#  (8, 8): 0.0,
#  (8, 9): 124952.1,
#  (8, 10): 109873.9,
#  (8, 11): 58923.6,
#  (8, 12): 107992.4,
#  (8, 13): 75150.5,
#  (9, 1): 72272.3,
#  (9, 2): 95519.3,
#  (9, 3): 92798.6,
#  (9, 4): 118368.1,
#  (9, 5): 81952.0,
#  (9, 6): 148405.4,
#  (9, 7): 78853.4,
#  (9, 8): 131181.9,
#  (9, 9): 0.0,
#  (9, 10): 27198.8,
#  (9, 11): 120263.9,
#  (9, 12): 109080.8,
#  (9, 13): 103329.3,
#  (10, 1): 51821.7,
#  (10, 2): 73328.5,
#  (10, 3): 72348.0,
#  (10, 4): 97079.6,
#  (10, 5): 93363.1,
#  (10, 6): 127116.9,
#  (10, 7): 90264.5,
#  (10, 8): 109893.4,
#  (10, 9): 25991.2,
#  (10, 10): 0.0,
#  (10, 11): 99813.2,
#  (10, 12): 69356.9,
#  (10, 13): 82878.6,
#  (11, 1): 62399.9,
#  (11, 2): 107255.8,
#  (11, 3): 66011.4,
#  (11, 4): 84627.4,
#  (11, 5): 143242.3,
#  (11, 6): 48358.8,
#  (11, 7): 140224.6,
#  (11, 8): 59825.2,
#  (11, 9): 119078.3,
#  (11, 10): 99835.2,
#  (11, 11): 0.0,
#  (11, 12): 59512.1,
#  (11, 13): 26670.2,
#  (12, 1): 76382.8,
#  (12, 2): 56285.6,
#  (12, 3): 16441.4,
#  (12, 4): 131961.4,
#  (12, 5): 174269.2,
#  (12, 6): 95692.8,
#  (12, 7): 177844.2,
#  (12, 8): 107159.1,
#  (12, 9): 106897.4,
#  (12, 10): 69356.9,
#  (12, 11): 58408.0,
#  (12, 12): 0.0,
#  (12, 13): 41473.4,
#  (13, 1): 40633.6,
#  (13, 2): 89769.7,
#  (13, 3): 48525.3,
#  (13, 4): 100279.1,
#  (13, 5): 145112.6,
#  (13, 6): 64010.4,
#  (13, 7): 142095.0,
#  (13, 8): 75476.8,
#  (13, 9): 101592.2,
#  (13, 10): 82349.1,
#  (13, 11): 26725.6,
#  (13, 12): 42026.0,
#  (13, 13): 0.0}

# %%
tauDistDF = vrv.convertMatricesDictionaryToDataframe(tauDist)
tauDistDF
# Out:
#           1         2         3         4         5         6         7   \
# 1        0.0   71329.5   83725.1   97658.2  138436.6   99732.5  135338.0
# 2    71845.8       0.0   54028.0  143673.7  168299.2  145045.6  165200.7
# 3    78183.2   54267.9       0.0  133761.7  182662.2   97493.1  179644.5
# 4    91015.1  137270.5  139294.0       0.0  102313.6   54779.7   99296.0
# 5   138436.6  161683.5  164355.5  100300.7       0.0  124248.9    7130.4
# 6    99683.5  144539.3  103295.0   54779.7  148063.6       0.0  145046.0
# 7   124951.7  158585.0  161337.9   97283.1    7130.4  121231.3       0.0
# 8    69397.3  115652.7  114491.7   28461.0  130840.1   29977.5  127822.5
# 9    72272.3   95519.3   92798.6  118368.1   81952.0  148405.4   78853.4
# 10   51821.7   73328.5   72348.0   97079.6   93363.1  127116.9   90264.5
# 11   62399.9  107255.8   66011.4   84627.4  143242.3   48358.8  140224.6
# 12   76382.8   56285.6   16441.4  131961.4  174269.2   95692.8  177844.2
# 13   40633.6   89769.7   48525.3  100279.1  145112.6   64010.4  142095.0
#
#           8         9         10        11        12        13
# 1    69402.2   71064.7   51821.7   62447.6   77225.8   40633.6
# 2   115417.6   93275.8   73844.8  107760.7   56847.2   90826.1
# 3   108959.5   91591.0   72348.0   60208.3   16441.4   43273.7
# 4    28461.0  110694.2   95616.0   83725.9  132794.7   82691.5
# 5   107025.4   78869.1   86092.3  119409.2  157856.2  121264.0
# 6    29977.5  142175.6  127097.4   47726.9   96795.7   63953.8
# 7   104007.8   75770.6   83074.6  116391.5  154838.6  118246.4
# 8        0.0  124952.1  109873.9   58923.6  107992.4   75150.5
# 9   131181.9       0.0   27198.8  120263.9  109080.8  103329.3
# 10  109893.4   25991.2       0.0   99813.2   69356.9   82878.6
# 11   59825.2  119078.3   99835.2       0.0   59512.1   26670.2
# 12  107159.1  106897.4   69356.9   58408.0       0.0   41473.4
# 13   75476.8  101592.2   82349.1   26725.6   42026.0       0.0

# %% [markdown]
# ## Export as .csv File

# %%
vrv.exportDataframe(nodes, 'nodes.csv')
# Out:
# Message: Data written to nodes.csv.

# %%
vrv.exportDataToCSV(tauTime, 'tauTime.csv')
vrv.exportDataToCSV(tauDist, 'tauDist.csv')
# Out:
# Message: Data written to tauTime.csv.
# Message: Data written to tauDist.csv.

# %% [markdown]
# ## Fitting into External Solver

# %% [markdown]
# - Notice: External Solver is not included in this package, here we plug in the solver that user is developing for their research.

# %%
import TSPSolver
n = []
for i in range(len(nodes)):
    n.append(TSPSolver.CNode(
        nodes.iloc[i]['id'],
        nodes.iloc[i]['nodeType'],
        nodes.iloc[i]['lat'],
        nodes.iloc[i]['lon']
    ))

# %%
seq = TSPSolver.TSPSolver(n, tauDist, tauTime)
# Out:
# Academic license - for non-commercial use only
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Optimize a model with 26 rows, 156 columns and 312 nonzeros
# Variable types: 0 continuous, 156 integer (156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e+03, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 26 rows, 156 columns, 312 nonzeros
# Variable types: 0 continuous, 156 integer (156 binary)
#
# Root relaxation: objective 5.407394e+05, 26 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    581030.30000 581030.300  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 11
#
# Explored 0 nodes (41 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 581030
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.810303000000e+05, best bound 5.810303000000e+05, gap 0.0000%

# %%
seq
# Out:
# [1, 2, 3, 12, 13, 11, 6, 8, 4, 5, 7, 9, 10, 1]

# %% [markdown]
# ## Process Routing Results

# %% [markdown]
# - Build Arc Dataframe

# %%
arcs = vrv.createArcsFromNodeSeq(
    nodeSeq = seq,
    nodes=nodes)

# %%
arcs
# Out:
#    odID objectID   startLat   startLon     endLat     endLon leafletColor  \
# 0     1     None  41.500000 -77.500000  41.056348 -77.237906       orange
# 1     2     None  41.056348 -77.237906  41.391310 -77.114275       orange
# 2     3     None  41.391310 -77.114275  41.336521 -77.051863       orange
# 3     4     None  41.336521 -77.051863  41.552584 -77.151014       orange
# 4     5     None  41.552584 -77.151014  41.716013 -77.013073       orange
# 5     6     None  41.716013 -77.013073  41.990585 -77.021575       orange
# 6     7     None  41.990585 -77.021575  41.938037 -77.303876       orange
# 7     8     None  41.938037 -77.303876  41.979934 -77.566735       orange
# 8     9     None  41.979934 -77.566735  41.496765 -77.958127       orange
# 9    10     None  41.496765 -77.958127  41.510352 -77.998732       orange
# 10   11     None  41.510352 -77.998732  41.371614 -77.780410       orange
# 11   12     None  41.371614 -77.780410  41.382004 -77.591294       orange
# 12   13     None  41.382004 -77.591294  41.500000 -77.500000       orange
#
#    leafletWeight leafletStyle  leafletOpacity leafletCurveType  \
# 0              3        solid             0.8         straight
# 1              3        solid             0.8         straight
# 2              3        solid             0.8         straight
# 3              3        solid             0.8         straight
# 4              3        solid             0.8         straight
# 5              3        solid             0.8         straight
# 6              3        solid             0.8         straight
# 7              3        solid             0.8         straight
# 8              3        solid             0.8         straight
# 9              3        solid             0.8         straight
# 10             3        solid             0.8         straight
# 11             3        solid             0.8         straight
# 12             3        solid             0.8         straight
#
#    leafletCurvature useArrows cesiumColor cesiumWeight cesiumStyle  \
# 0                 0      True      orange            3       solid
# 1                 0      True      orange            3       solid
# 2                 0      True      orange            3       solid
# 3                 0      True      orange            3       solid
# 4                 0      True      orange            3       solid
# 5                 0      True      orange            3       solid
# 6                 0      True      orange            3       solid
# 7                 0      True      orange            3       solid
# 8                 0      True      orange            3       solid
# 9                 0      True      orange            3       solid
# 10                0      True      orange            3       solid
# 11                0      True      orange            3       solid
# 12                0      True      orange            3       solid
#
#     cesiumOpacity popupText startElevMeters endElevMeters
# 0             0.8      None            None          None
# 1             0.8      None            None          None
# 2             0.8      None            None          None
# 3             0.8      None            None          None
# 4             0.8      None            None          None
# 5             0.8      None            None          None
# 6             0.8      None            None          None
# 7             0.8      None            None          None
# 8             0.8      None            None          None
# 9             0.8      None            None          None
# 10            0.8      None            None          None
# 11            0.8      None            None          None
# 12            0.8      None            None          None

# %%
vrv.createLeaflet(arcs=arcs, nodes=nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Build Assignments Dataframe

# %%
route = vrv.createAssignmentsFromNodeSeq2D(
    nodeSeq=seq, 
    nodes=nodes, 
    expDurationArgs = {
        'timeSecDict' : tauTime
    },
    routeType='fastest', 
    dataProvider='osrm-online')
# Out:
# Warning: `objectID` is None; the Assignments dataframe can not be visualized by Cesium.
# Warning: `modelFile` is None; the Assignments dataframe can not be visualized by Cesium.
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
# Warning: Expected duration time has been provided; speed from data provider will be ignored. To calculate based on data from the data provider, leave `expDurationSec` at its default value (None).
#
# Message: The origin point (lat: 41.5, lon: -77.5) is 1416.6 meters away from the road. You might find a gap between the origin point and the route.
# Message: The destination point (lat: 41.716013, lon: -77.013073) is 1332.0 meters away from the road. You might find a gap between destination point and the route.
# Message: The origin point (lat: 41.716013, lon: -77.013073) is 1332.0 meters away from the road. You might find a gap between the origin point and the route.
# Message: The destination point (lat: 41.5, lon: -77.5) is 1416.6 meters away from the road. You might find a gap between destination point and the route.

# %%
route
# Out:
#     odID objectID modelFile modelScale modelMinPxSize  startTimeSec  \
# 0      1     None      None        100             75      0.000000
# 1      1     None      None        100             75     23.795035
# 2      1     None      None        100             75     28.256550
# 3      1     None      None        100             75     42.748115
# 4      1     None      None        100             75     67.532786
# 5      1     None      None        100             75     87.040502
# 6      1     None      None        100             75    117.469784
# 7      1     None      None        100             75    128.548294
# 8      1     None      None        100             75    136.550161
# 9      1     None      None        100             75    148.368361
# 10     1     None      None        100             75    230.941717
# 11     1     None      None        100             75    299.075318
# 12     1     None      None        100             75    304.789062
# 13     1     None      None        100             75    335.440807
# 14     1     None      None        100             75    369.722107
# 15     1     None      None        100             75    392.338587
# 16     1     None      None        100             75    402.268535
# 17     1     None      None        100             75    535.834295
# 18     1     None      None        100             75    542.511300
# 19     1     None      None        100             75    596.717981
# 20     1     None      None        100             75    692.614482
# 21     1     None      None        100             75    692.787944
# 22     1     None      None        100             75    715.699919
# 23     1     None      None        100             75    725.247065
# 24     1     None      None        100             75    745.671437
# 25     1     None      None        100             75    826.735807
# 26     1     None      None        100             75    846.680050
# 27     1     None      None        100             75    886.074254
# 28     1     None      None        100             75    901.876721
# 29     1     None      None        100             75    904.070689
# ..   ...      ...       ...        ...            ...           ...
# 918   13     None      None        100             75  38860.657031
# 919   13     None      None        100             75  38862.191919
# 920   13     None      None        100             75  38864.674521
# 921   13     None      None        100             75  38882.555923
# 922   13     None      None        100             75  38927.132735
# 923   13     None      None        100             75  38949.700795
# 924   13     None      None        100             75  39041.429801
# 925   13     None      None        100             75  39064.541154
# 926   13     None      None        100             75  39075.344300
# 927   13     None      None        100             75  39101.270520
# 928   13     None      None        100             75  39101.466802
# 929   13     None      None        100             75  39209.979219
# 930   13     None      None        100             75  39271.317202
# 931   13     None      None        100             75  39278.872618
# 932   13     None      None        100             75  39430.009972
# 933   13     None      None        100             75  39441.246281
# 934   13     None      None        100             75  39466.838131
# 935   13     None      None        100             75  39505.629397
# 936   13     None      None        100             75  39540.313613
# 937   13     None      None        100             75  39546.779044
# 938   13     None      None        100             75  39623.876140
# 939   13     None      None        100             75  39717.312650
# 940   13     None      None        100             75  39730.685624
# 941   13     None      None        100             75  39739.740197
# 942   13     None      None        100             75  39752.276171
# 943   13     None      None        100             75  39786.708656
# 944   13     None      None        100             75  39808.782761
# 945   13     None      None        100             75  39836.828044
# 946   13     None      None        100             75  39853.226085
# 947   13     None      None        100             75  39858.274546
#
#       startLat   startLon startAltMeters    endTimeSec  ...  ganttColor  \
# 0    41.488336 -77.493134              0     23.795035  ...    darkgray
# 1    41.485928 -77.496815              0     28.256550  ...    darkgray
# 2    41.485309 -77.496416              0     42.748115  ...    darkgray
# 3    41.483462 -77.498088              0     67.532786  ...    darkgray
# 4    41.480133 -77.500583              0     87.040502  ...    darkgray
# 5    41.477310 -77.501963              0    117.469784  ...    darkgray
# 6    41.472627 -77.501585              0    128.548294  ...    darkgray
# 7    41.470994 -77.500919              0    136.550161  ...    darkgray
# 8    41.469803 -77.500491              0    148.368361  ...    darkgray
# 9    41.468012 -77.500937              0    230.941717  ...    darkgray
# 10   41.457221 -77.509918              0    299.075318  ...    darkgray
# 11   41.448244 -77.517170              0    304.789062  ...    darkgray
# 12   41.447371 -77.517327              0    335.440807  ...    darkgray
# 13   41.442809 -77.515687              0    369.722107  ...    darkgray
# 14   41.439213 -77.510539              0    392.338587  ...    darkgray
# 15   41.437657 -77.506392              0    402.268535  ...    darkgray
# 16   41.437184 -77.504457              0    535.834295  ...    darkgray
# 17   41.420655 -77.488136              0    542.511300  ...    darkgray
# 18   41.419930 -77.487165              0    596.717981  ...    darkgray
# 19   41.415567 -77.477695              0    692.614482  ...    darkgray
# 20   41.404547 -77.464601              0    692.787944  ...    darkgray
# 21   41.404528 -77.464576              0    715.699919  ...    darkgray
# 22   41.402383 -77.460848              0    725.247065  ...    darkgray
# 23   41.401514 -77.459270              0    745.671437  ...    darkgray
# 24   41.399290 -77.456309              0    826.735807  ...    darkgray
# 25   41.387000 -77.453288              0    846.680050  ...    darkgray
# 26   41.386114 -77.449378              0    886.074254  ...    darkgray
# 27   41.383215 -77.442291              0    901.876721  ...    darkgray
# 28   41.381182 -77.440508              0    904.070689  ...    darkgray
# 29   41.380898 -77.440264              0    905.427127  ...    darkgray
# ..         ...        ...            ...           ...  ...         ...
# 918  41.380722 -77.440114              0  38862.191919  ...    darkgray
# 919  41.380898 -77.440264              0  38864.674521  ...    darkgray
# 920  41.381182 -77.440508              0  38882.555923  ...    darkgray
# 921  41.383215 -77.442291              0  38927.132735  ...    darkgray
# 922  41.386114 -77.449378              0  38949.700795  ...    darkgray
# 923  41.387000 -77.453288              0  39041.429801  ...    darkgray
# 924  41.399290 -77.456309              0  39064.541154  ...    darkgray
# 925  41.401514 -77.459270              0  39075.344300  ...    darkgray
# 926  41.402383 -77.460848              0  39101.270520  ...    darkgray
# 927  41.404528 -77.464576              0  39101.466802  ...    darkgray
# 928  41.404547 -77.464601              0  39209.979219  ...    darkgray
# 929  41.415567 -77.477695              0  39271.317202  ...    darkgray
# 930  41.419930 -77.487165              0  39278.872618  ...    darkgray
# 931  41.420655 -77.488136              0  39430.009972  ...    darkgray
# 932  41.437184 -77.504457              0  39441.246281  ...    darkgray
# 933  41.437657 -77.506392              0  39466.838131  ...    darkgray
# 934  41.439213 -77.510539              0  39505.629397  ...    darkgray
# 935  41.442809 -77.515687              0  39540.313613  ...    darkgray
# 936  41.447371 -77.517327              0  39546.779044  ...    darkgray
# 937  41.448244 -77.517170              0  39623.876140  ...    darkgray
# 938  41.457221 -77.509918              0  39717.312650  ...    darkgray
# 939  41.468012 -77.500937              0  39730.685624  ...    darkgray
# 940  41.469803 -77.500491              0  39739.740197  ...    darkgray
# 941  41.470994 -77.500919              0  39752.276171  ...    darkgray
# 942  41.472627 -77.501585              0  39786.708656  ...    darkgray
# 943  41.477310 -77.501963              0  39808.782761  ...    darkgray
# 944  41.480133 -77.500583              0  39836.828044  ...    darkgray
# 945  41.483462 -77.498088              0  39853.226085  ...    darkgray
# 946  41.485309 -77.496416              0  39858.274546  ...    darkgray
# 947  41.485928 -77.496815              0  39885.200000  ...    darkgray
#
#      popupText startElevMeters endElevMeters wayname waycategory  surface  \
# 0         None            None          None    None        None     None
# 1         None            None          None    None        None     None
# 2         None            None          None    None        None     None
# 3         None            None          None    None        None     None
# 4         None            None          None    None        None     None
# 5         None            None          None    None        None     None
# 6         None            None          None    None        None     None
# 7         None            None          None    None        None     None
# 8         None            None          None    None        None     None
# 9         None            None          None    None        None     None
# 10        None            None          None    None        None     None
# 11        None            None          None    None        None     None
# 12        None            None          None    None        None     None
# 13        None            None          None    None        None     None
# 14        None            None          None    None        None     None
# 15        None            None          None    None        None     None
# 16        None            None          None    None        None     None
# 17        None            None          None    None        None     None
# 18        None            None          None    None        None     None
# 19        None            None          None    None        None     None
# 20        None            None          None    None        None     None
# 21        None            None          None    None        None     None
# 22        None            None          None    None        None     None
# 23        None            None          None    None        None     None
# 24        None            None          None    None        None     None
# 25        None            None          None    None        None     None
# 26        None            None          None    None        None     None
# 27        None            None          None    None        None     None
# 28        None            None          None    None        None     None
# 29        None            None          None    None        None     None
# ..         ...             ...           ...     ...         ...      ...
# 918       None            None          None    None        None     None
# 919       None            None          None    None        None     None
# 920       None            None          None    None        None     None
# 921       None            None          None    None        None     None
# 922       None            None          None    None        None     None
# 923       None            None          None    None        None     None
# 924       None            None          None    None        None     None
# 925       None            None          None    None        None     None
# 926       None            None          None    None        None     None
# 927       None            None          None    None        None     None
# 928       None            None          None    None        None     None
# 929       None            None          None    None        None     None
# 930       None            None          None    None        None     None
# 931       None            None          None    None        None     None
# 932       None            None          None    None        None     None
# 933       None            None          None    None        None     None
# 934       None            None          None    None        None     None
# 935       None            None          None    None        None     None
# 936       None            None          None    None        None     None
# 937       None            None          None    None        None     None
# 938       None            None          None    None        None     None
# 939       None            None          None    None        None     None
# 940       None            None          None    None        None     None
# 941       None            None          None    None        None     None
# 942       None            None          None    None        None     None
# 943       None            None          None    None        None     None
# 944       None            None          None    None        None     None
# 945       None            None          None    None        None     None
# 946       None            None          None    None        None     None
# 947       None            None          None    None        None     None
#
#     waytype steepness tollway
# 0      None      None    None
# 1      None      None    None
# 2      None      None    None
# 3      None      None    None
# 4      None      None    None
# 5      None      None    None
# 6      None      None    None
# 7      None      None    None
# 8      None      None    None
# 9      None      None    None
# 10     None      None    None
# 11     None      None    None
# 12     None      None    None
# 13     None      None    None
# 14     None      None    None
# 15     None      None    None
# 16     None      None    None
# 17     None      None    None
# 18     None      None    None
# 19     None      None    None
# 20     None      None    None
# 21     None      None    None
# 22     None      None    None
# 23     None      None    None
# 24     None      None    None
# 25     None      None    None
# 26     None      None    None
# 27     None      None    None
# 28     None      None    None
# 29     None      None    None
# ..      ...       ...     ...
# 918    None      None    None
# 919    None      None    None
# 920    None      None    None
# 921    None      None    None
# 922    None      None    None
# 923    None      None    None
# 924    None      None    None
# 925    None      None    None
# 926    None      None    None
# 927    None      None    None
# 928    None      None    None
# 929    None      None    None
# 930    None      None    None
# 931    None      None    None
# 932    None      None    None
# 933    None      None    None
# 934    None      None    None
# 935    None      None    None
# 936    None      None    None
# 937    None      None    None
# 938    None      None    None
# 939    None      None    None
# 940    None      None    None
# 941    None      None    None
# 942    None      None    None
# 943    None      None    None
# 944    None      None    None
# 945    None      None    None
# 946    None      None    None
# 947    None      None    None
#
# [948 rows x 34 columns]

# %%
vrv.createLeaflet(
    arcs = route, 
    nodes = nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Add 3d model into assignments dataframe

# %%
route['objectID'] = 1
route['modelFile'] = '/veroviz/models/ub_truck.gltf'
route
# Out:
#     odID  objectID                      modelFile modelScale modelMinPxSize  \
# 0      1         1  /veroviz/models/ub_truck.gltf        100             75
# 1      1         1  /veroviz/models/ub_truck.gltf        100             75
# 2      1         1  /veroviz/models/ub_truck.gltf        100             75
# 3      1         1  /veroviz/models/ub_truck.gltf        100             75
# 4      1         1  /veroviz/models/ub_truck.gltf        100             75
# 5      1         1  /veroviz/models/ub_truck.gltf        100             75
# 6      1         1  /veroviz/models/ub_truck.gltf        100             75
# 7      1         1  /veroviz/models/ub_truck.gltf        100             75
# 8      1         1  /veroviz/models/ub_truck.gltf        100             75
# 9      1         1  /veroviz/models/ub_truck.gltf        100             75
# 10     1         1  /veroviz/models/ub_truck.gltf        100             75
# 11     1         1  /veroviz/models/ub_truck.gltf        100             75
# 12     1         1  /veroviz/models/ub_truck.gltf        100             75
# 13     1         1  /veroviz/models/ub_truck.gltf        100             75
# 14     1         1  /veroviz/models/ub_truck.gltf        100             75
# 15     1         1  /veroviz/models/ub_truck.gltf        100             75
# 16     1         1  /veroviz/models/ub_truck.gltf        100             75
# 17     1         1  /veroviz/models/ub_truck.gltf        100             75
# 18     1         1  /veroviz/models/ub_truck.gltf        100             75
# 19     1         1  /veroviz/models/ub_truck.gltf        100             75
# 20     1         1  /veroviz/models/ub_truck.gltf        100             75
# 21     1         1  /veroviz/models/ub_truck.gltf        100             75
# 22     1         1  /veroviz/models/ub_truck.gltf        100             75
# 23     1         1  /veroviz/models/ub_truck.gltf        100             75
# 24     1         1  /veroviz/models/ub_truck.gltf        100             75
# 25     1         1  /veroviz/models/ub_truck.gltf        100             75
# 26     1         1  /veroviz/models/ub_truck.gltf        100             75
# 27     1         1  /veroviz/models/ub_truck.gltf        100             75
# 28     1         1  /veroviz/models/ub_truck.gltf        100             75
# 29     1         1  /veroviz/models/ub_truck.gltf        100             75
# ..   ...       ...                            ...        ...            ...
# 918   13         1  /veroviz/models/ub_truck.gltf        100             75
# 919   13         1  /veroviz/models/ub_truck.gltf        100             75
# 920   13         1  /veroviz/models/ub_truck.gltf        100             75
# 921   13         1  /veroviz/models/ub_truck.gltf        100             75
# 922   13         1  /veroviz/models/ub_truck.gltf        100             75
# 923   13         1  /veroviz/models/ub_truck.gltf        100             75
# 924   13         1  /veroviz/models/ub_truck.gltf        100             75
# 925   13         1  /veroviz/models/ub_truck.gltf        100             75
# 926   13         1  /veroviz/models/ub_truck.gltf        100             75
# 927   13         1  /veroviz/models/ub_truck.gltf        100             75
# 928   13         1  /veroviz/models/ub_truck.gltf        100             75
# 929   13         1  /veroviz/models/ub_truck.gltf        100             75
# 930   13         1  /veroviz/models/ub_truck.gltf        100             75
# 931   13         1  /veroviz/models/ub_truck.gltf        100             75
# 932   13         1  /veroviz/models/ub_truck.gltf        100             75
# 933   13         1  /veroviz/models/ub_truck.gltf        100             75
# 934   13         1  /veroviz/models/ub_truck.gltf        100             75
# 935   13         1  /veroviz/models/ub_truck.gltf        100             75
# 936   13         1  /veroviz/models/ub_truck.gltf        100             75
# 937   13         1  /veroviz/models/ub_truck.gltf        100             75
# 938   13         1  /veroviz/models/ub_truck.gltf        100             75
# 939   13         1  /veroviz/models/ub_truck.gltf        100             75
# 940   13         1  /veroviz/models/ub_truck.gltf        100             75
# 941   13         1  /veroviz/models/ub_truck.gltf        100             75
# 942   13         1  /veroviz/models/ub_truck.gltf        100             75
# 943   13         1  /veroviz/models/ub_truck.gltf        100             75
# 944   13         1  /veroviz/models/ub_truck.gltf        100             75
# 945   13         1  /veroviz/models/ub_truck.gltf        100             75
# 946   13         1  /veroviz/models/ub_truck.gltf        100             75
# 947   13         1  /veroviz/models/ub_truck.gltf        100             75
#
#      startTimeSec   startLat   startLon startAltMeters    endTimeSec  ...  \
# 0        0.000000  41.488336 -77.493134              0     23.795035  ...
# 1       23.795035  41.485928 -77.496815              0     28.256550  ...
# 2       28.256550  41.485309 -77.496416              0     42.748115  ...
# 3       42.748115  41.483462 -77.498088              0     67.532786  ...
# 4       67.532786  41.480133 -77.500583              0     87.040502  ...
# 5       87.040502  41.477310 -77.501963              0    117.469784  ...
# 6      117.469784  41.472627 -77.501585              0    128.548294  ...
# 7      128.548294  41.470994 -77.500919              0    136.550161  ...
# 8      136.550161  41.469803 -77.500491              0    148.368361  ...
# 9      148.368361  41.468012 -77.500937              0    230.941717  ...
# 10     230.941717  41.457221 -77.509918              0    299.075318  ...
# 11     299.075318  41.448244 -77.517170              0    304.789062  ...
# 12     304.789062  41.447371 -77.517327              0    335.440807  ...
# 13     335.440807  41.442809 -77.515687              0    369.722107  ...
# 14     369.722107  41.439213 -77.510539              0    392.338587  ...
# 15     392.338587  41.437657 -77.506392              0    402.268535  ...
# 16     402.268535  41.437184 -77.504457              0    535.834295  ...
# 17     535.834295  41.420655 -77.488136              0    542.511300  ...
# 18     542.511300  41.419930 -77.487165              0    596.717981  ...
# 19     596.717981  41.415567 -77.477695              0    692.614482  ...
# 20     692.614482  41.404547 -77.464601              0    692.787944  ...
# 21     692.787944  41.404528 -77.464576              0    715.699919  ...
# 22     715.699919  41.402383 -77.460848              0    725.247065  ...
# 23     725.247065  41.401514 -77.459270              0    745.671437  ...
# 24     745.671437  41.399290 -77.456309              0    826.735807  ...
# 25     826.735807  41.387000 -77.453288              0    846.680050  ...
# 26     846.680050  41.386114 -77.449378              0    886.074254  ...
# 27     886.074254  41.383215 -77.442291              0    901.876721  ...
# 28     901.876721  41.381182 -77.440508              0    904.070689  ...
# 29     904.070689  41.380898 -77.440264              0    905.427127  ...
# ..            ...        ...        ...            ...           ...  ...
# 918  38860.657031  41.380722 -77.440114              0  38862.191919  ...
# 919  38862.191919  41.380898 -77.440264              0  38864.674521  ...
# 920  38864.674521  41.381182 -77.440508              0  38882.555923  ...
# 921  38882.555923  41.383215 -77.442291              0  38927.132735  ...
# 922  38927.132735  41.386114 -77.449378              0  38949.700795  ...
# 923  38949.700795  41.387000 -77.453288              0  39041.429801  ...
# 924  39041.429801  41.399290 -77.456309              0  39064.541154  ...
# 925  39064.541154  41.401514 -77.459270              0  39075.344300  ...
# 926  39075.344300  41.402383 -77.460848              0  39101.270520  ...
# 927  39101.270520  41.404528 -77.464576              0  39101.466802  ...
# 928  39101.466802  41.404547 -77.464601              0  39209.979219  ...
# 929  39209.979219  41.415567 -77.477695              0  39271.317202  ...
# 930  39271.317202  41.419930 -77.487165              0  39278.872618  ...
# 931  39278.872618  41.420655 -77.488136              0  39430.009972  ...
# 932  39430.009972  41.437184 -77.504457              0  39441.246281  ...
# 933  39441.246281  41.437657 -77.506392              0  39466.838131  ...
# 934  39466.838131  41.439213 -77.510539              0  39505.629397  ...
# 935  39505.629397  41.442809 -77.515687              0  39540.313613  ...
# 936  39540.313613  41.447371 -77.517327              0  39546.779044  ...
# 937  39546.779044  41.448244 -77.517170              0  39623.876140  ...
# 938  39623.876140  41.457221 -77.509918              0  39717.312650  ...
# 939  39717.312650  41.468012 -77.500937              0  39730.685624  ...
# 940  39730.685624  41.469803 -77.500491              0  39739.740197  ...
# 941  39739.740197  41.470994 -77.500919              0  39752.276171  ...
# 942  39752.276171  41.472627 -77.501585              0  39786.708656  ...
# 943  39786.708656  41.477310 -77.501963              0  39808.782761  ...
# 944  39808.782761  41.480133 -77.500583              0  39836.828044  ...
# 945  39836.828044  41.483462 -77.498088              0  39853.226085  ...
# 946  39853.226085  41.485309 -77.496416              0  39858.274546  ...
# 947  39858.274546  41.485928 -77.496815              0  39885.200000  ...
#
#      ganttColor  popupText startElevMeters endElevMeters wayname waycategory  \
# 0      darkgray       None            None          None    None        None
# 1      darkgray       None            None          None    None        None
# 2      darkgray       None            None          None    None        None
# 3      darkgray       None            None          None    None        None
# 4      darkgray       None            None          None    None        None
# 5      darkgray       None            None          None    None        None
# 6      darkgray       None            None          None    None        None
# 7      darkgray       None            None          None    None        None
# 8      darkgray       None            None          None    None        None
# 9      darkgray       None            None          None    None        None
# 10     darkgray       None            None          None    None        None
# 11     darkgray       None            None          None    None        None
# 12     darkgray       None            None          None    None        None
# 13     darkgray       None            None          None    None        None
# 14     darkgray       None            None          None    None        None
# 15     darkgray       None            None          None    None        None
# 16     darkgray       None            None          None    None        None
# 17     darkgray       None            None          None    None        None
# 18     darkgray       None            None          None    None        None
# 19     darkgray       None            None          None    None        None
# 20     darkgray       None            None          None    None        None
# 21     darkgray       None            None          None    None        None
# 22     darkgray       None            None          None    None        None
# 23     darkgray       None            None          None    None        None
# 24     darkgray       None            None          None    None        None
# 25     darkgray       None            None          None    None        None
# 26     darkgray       None            None          None    None        None
# 27     darkgray       None            None          None    None        None
# 28     darkgray       None            None          None    None        None
# 29     darkgray       None            None          None    None        None
# ..          ...        ...             ...           ...     ...         ...
# 918    darkgray       None            None          None    None        None
# 919    darkgray       None            None          None    None        None
# 920    darkgray       None            None          None    None        None
# 921    darkgray       None            None          None    None        None
# 922    darkgray       None            None          None    None        None
# 923    darkgray       None            None          None    None        None
# 924    darkgray       None            None          None    None        None
# 925    darkgray       None            None          None    None        None
# 926    darkgray       None            None          None    None        None
# 927    darkgray       None            None          None    None        None
# 928    darkgray       None            None          None    None        None
# 929    darkgray       None            None          None    None        None
# 930    darkgray       None            None          None    None        None
# 931    darkgray       None            None          None    None        None
# 932    darkgray       None            None          None    None        None
# 933    darkgray       None            None          None    None        None
# 934    darkgray       None            None          None    None        None
# 935    darkgray       None            None          None    None        None
# 936    darkgray       None            None          None    None        None
# 937    darkgray       None            None          None    None        None
# 938    darkgray       None            None          None    None        None
# 939    darkgray       None            None          None    None        None
# 940    darkgray       None            None          None    None        None
# 941    darkgray       None            None          None    None        None
# 942    darkgray       None            None          None    None        None
# 943    darkgray       None            None          None    None        None
# 944    darkgray       None            None          None    None        None
# 945    darkgray       None            None          None    None        None
# 946    darkgray       None            None          None    None        None
# 947    darkgray       None            None          None    None        None
#
#      surface waytype steepness tollway
# 0       None    None      None    None
# 1       None    None      None    None
# 2       None    None      None    None
# 3       None    None      None    None
# 4       None    None      None    None
# 5       None    None      None    None
# 6       None    None      None    None
# 7       None    None      None    None
# 8       None    None      None    None
# 9       None    None      None    None
# 10      None    None      None    None
# 11      None    None      None    None
# 12      None    None      None    None
# 13      None    None      None    None
# 14      None    None      None    None
# 15      None    None      None    None
# 16      None    None      None    None
# 17      None    None      None    None
# 18      None    None      None    None
# 19      None    None      None    None
# 20      None    None      None    None
# 21      None    None      None    None
# 22      None    None      None    None
# 23      None    None      None    None
# 24      None    None      None    None
# 25      None    None      None    None
# 26      None    None      None    None
# 27      None    None      None    None
# 28      None    None      None    None
# 29      None    None      None    None
# ..       ...     ...       ...     ...
# 918     None    None      None    None
# 919     None    None      None    None
# 920     None    None      None    None
# 921     None    None      None    None
# 922     None    None      None    None
# 923     None    None      None    None
# 924     None    None      None    None
# 925     None    None      None    None
# 926     None    None      None    None
# 927     None    None      None    None
# 928     None    None      None    None
# 929     None    None      None    None
# 930     None    None      None    None
# 931     None    None      None    None
# 932     None    None      None    None
# 933     None    None      None    None
# 934     None    None      None    None
# 935     None    None      None    None
# 936     None    None      None    None
# 937     None    None      None    None
# 938     None    None      None    None
# 939     None    None      None    None
# 940     None    None      None    None
# 941     None    None      None    None
# 942     None    None      None    None
# 943     None    None      None    None
# 944     None    None      None    None
# 945     None    None      None    None
# 946     None    None      None    None
# 947     None    None      None    None
#
# [948 rows x 34 columns]

# %%
vrv.createCesium(
    nodes=nodes, 
    assignments=route,
    cesiumDir='D:/Cesium',
    problemDir='veroviz/demo'
)
# Out:
# Message: File selector was written to D:/Cesium/veroviz/demo/;veroviz;demo.vrv ...
# Message: Configs were written to D:/Cesium/veroviz/demo/config.js ...
# Message: Nodes were written to D:/Cesium/veroviz/demo/displayNodes.js ...
# Message: Assignments (.js) were written to D:/Cesium/veroviz/demo/displayPaths.js ...
# Message: Assignments (.czml) were written to D:/Cesium/veroviz/demo/routes.czml ...
